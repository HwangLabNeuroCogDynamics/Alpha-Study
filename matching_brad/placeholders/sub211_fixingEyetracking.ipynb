# %%
import os
import pandas as pd
import numpy as np

# %%
s211=pd.read_csv('/data/backed_up/shared/AlphaStudy_data/placeholders/eyetracking_compiled_trials/sub_211_trialsCompiled.csv')

# %%
600-len(s211)
# Out:
# 63

# %%
s211.head()
# Out:
#    Unnamed: 0  Eyetrack_trial  Timestamp_start_cue  Timestamp_start_mask  \
# 0           0             0.0         1.050686e+09          1.050274e+09
# 1           1             1.0         1.056219e+09          1.055805e+09
# 2           2             2.0         1.061802e+09          1.061390e+09
# 3           3             3.0         1.066286e+09          1.065872e+09
# 4           4             4.0         1.071401e+09          1.070989e+09
#
#    Timestamp_start_probe  Timestamp_stop_cue  Timestamp_stop_mask  \
# 0           1.051519e+09        1.051517e+09         1.050684e+09
# 1           1.056303e+09        1.056301e+09         1.056217e+09
# 2           1.061886e+09        1.061884e+09         1.061800e+09
# 3           1.066369e+09        1.066367e+09         1.066284e+09
# 4           1.071485e+09        1.071483e+09         1.071399e+09
#
#    Timestamp_stop_probe      TrialTrigs(m,c,p)  \
# 0          1.052034e+09  (125.0, 103.0, 115.0)
# ...

# %%
empty_df=pd.DataFrame(columns=s211.columns)

# %%
empty_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Eyetrack_trial, Timestamp_start_cue, Timestamp_start_mask, Timestamp_start_probe, Timestamp_stop_cue, Timestamp_stop_mask, Timestamp_stop_probe, TrialTrigs(m,c,p), leftX_cue, leftX_mask, leftX_probe, leftY_cue, leftY_mask, leftY_probe, rightX_cue, rightX_mask, rightX_probe, rightY_cue, rightY_mask, rightY_probe]
# Index: []
#
# [0 rows x 21 columns]

# %%
empty_rows={}
for col in s211.columns:
    empty_rows[col]=np.nan

# %%
empty_rows
# Out:
# {'Unnamed: 0': nan,
#  'Eyetrack_trial': nan,
#  'Timestamp_start_cue': nan,
#  'Timestamp_start_mask': nan,
#  'Timestamp_start_probe': nan,
#  'Timestamp_stop_cue': nan,
#  'Timestamp_stop_mask': nan,
#  'Timestamp_stop_probe': nan,
#  'TrialTrigs(m,c,p)': nan,
#  'leftX_cue': nan,
#  'leftX_mask': nan,
#  'leftX_probe': nan,
#  'leftY_cue': nan,
#  'leftY_mask': nan,
#  'leftY_probe': nan,
#  'rightX_cue': nan,
#  'rightX_mask': nan,
#  'rightX_probe': nan,
#  'rightY_cue': nan,
#  'rightY_mask': nan,
#  'rightY_probe': nan}

# %%
for n in range(63):
    empty_df=empty_df.append(empty_rows, ignore_index=True)

# %%
empty_df
# Out:
#    Unnamed: 0 Eyetrack_trial Timestamp_start_cue Timestamp_start_mask  \
# 0         NaN            NaN                 NaN                  NaN
# 1         NaN            NaN                 NaN                  NaN
# 2         NaN            NaN                 NaN                  NaN
# 3         NaN            NaN                 NaN                  NaN
# 4         NaN            NaN                 NaN                  NaN
# 5         NaN            NaN                 NaN                  NaN
# 6         NaN            NaN                 NaN                  NaN
# 7         NaN            NaN                 NaN                  NaN
# 8         NaN            NaN                 NaN                  NaN
# 9         NaN            NaN                 NaN                  NaN
# 10        NaN            NaN                 NaN                  NaN
# 11        NaN            NaN                 NaN                  NaN
# ...

# %%
filled_emptys=pd.concat([empty_df,s211])

# %%
filled_emptys.to_csv('/data/backed_up/shared/AlphaStudy_data/placeholders/eyetracking_compiled_trials/sub_211_trialsCompiled_TRUNCATED_TO_MATCH.csv')
