# %%
import pandas as pd
import mne
import os
import numpy as np
from mne.time_frequency import tfr_morlet

# %%
ROOT_preproc='/data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/'
list_subs=os.listdir(ROOT_preproc)

# %%
preproc_cue_eps={}
preproc_probe_eps={}
for s in list_subs:
    cue=mne.read_epochs(ROOT_preproc+s+'/'+'cue-epo.fif')
    probe=mne.read_epochs(ROOT_preproc+s+'/'+'probe events-epo.fif')
    preproc_cue_eps[s]=cue
    preproc_probe_eps[s]=probe
# Out:
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/224/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 660 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/224/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 660 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/214/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 592 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/214/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 595 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/211/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 590 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 38 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/211/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 582 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 38 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/206/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 597 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/206/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 593 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/225/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 600 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/225/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 595 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/226/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 598 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/226/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 592 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/233/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 596 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/233/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 593 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/223/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 589 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/223/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 583 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/197/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 578 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/197/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 577 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/228/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 578 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/228/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 548 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 38 columns
# 0 projection items activated

# %%
preproc_cue_eps
# Out:
# {'224': <EpochsFIF  |   660 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~386.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 110
#   'disShortCue_trig': 110
#   'neutLongCue_trig': 110
#   'neutShortCue_trig': 110
#   'tarLongCue_trig': 110
#   'tarShortCue_trig': 110>,
#  '214': <EpochsFIF  |   592 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~346.3 MB, data loaded, with metadata,
#   'disLongCue_trig': 99
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 98
#   'tarLongCue_trig': 98
#   'tarShortCue_trig': 99>,
#  '211': <EpochsFIF  |   590 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~345.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 97
#   'disShortCue_trig': 98
#   'neutLongCue_trig': 99
#   'neutShortCue_trig': 99
#   'tarLongCue_trig': 99
#   'tarShortCue_trig': 98>,
#  '206': <EpochsFIF  |   597 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~349.2 MB, data loaded, with metadata,
#   'disLongCue_trig': 100
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 99
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 100>,
#  '225': <EpochsFIF  |   600 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~351.0 MB, data loaded, with metadata,
#   'disLongCue_trig': 100
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 100
#   'neutShortCue_trig': 100
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 100>,
#  '226': <EpochsFIF  |   598 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~349.8 MB, data loaded, with metadata,
#   'disLongCue_trig': 99
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 100
#   'neutShortCue_trig': 100
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 99>,
#  '233': <EpochsFIF  |   596 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~348.6 MB, data loaded, with metadata,
#   'disLongCue_trig': 98
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 100
#   'neutShortCue_trig': 99
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 99>,
#  '223': <EpochsFIF  |   589 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~344.5 MB, data loaded, with metadata,
#   'disLongCue_trig': 100
#   'disShortCue_trig': 98
#   'neutLongCue_trig': 97
#   'neutShortCue_trig': 96
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 98>,
#  '197': <EpochsFIF  |   578 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~338.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 96
#   'disShortCue_trig': 98
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 93
#   'tarLongCue_trig': 99
#   'tarShortCue_trig': 94>,
#  '228': <EpochsFIF  |   578 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~338.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 98
#   'disShortCue_trig': 96
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 98
#   'tarLongCue_trig': 94
#   'tarShortCue_trig': 94>}

# %%
example=preproc_cue_eps['214']

# %%
freqs=np.arange(.5,38.,2.)
n_cycles = freqs / 2.


tfr_disLongCue=mne.time_frequency.tfr_morlet(example['disLongCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
# Out:
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/scipy/fftpack/basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x

# %%
print(freqs)
print(len(freqs))

# %%
#tfr_disLongCue.plot(vmin=-15,vmax=15)

# %%
tfr_disLongCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
#tfr_disLongCue.plot_topo(vmin=-10,vmax=10)
tfr_disLongCue_frontals=tfr_disLongCue.copy().pick_channels(['F1','Fz','F2','FC1','FCz','FC2'])

# %%
tfr_disLongCue_frontals.plot(picks='all',vmin=-7.50,vmax=7.5)

# %%
#tfr_disLongCue_frontals_avged=tfr_disLongCue_frontals.data.mean(axis=0)

# %%
tfr_disLongCue.data.shape

# %%
#tfr_disLongCue_frontals.data.shape

# %%
tfr_disLongCue_posts=tfr_disLongCue.copy().pick_channels(['P1','Pz','P2','P3','P4','PO3','PO4','POz'])

# %%
tfr_disLongCue_posts.plot(picks='all',vmin=-7.50,vmax=7.5)

# %%
#tfr_disShortCue=mne.time_frequency.tfr_morlet(example['disShortCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
#                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
#tfr_disShortCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))

# %%
#dislongMinusShort=tfr_disLongCue-tfr_disShortCue

#dislongMinusShort.plot(vmin=-10,vmax=10,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])

# %%
tfr_neutLongCue=mne.time_frequency.tfr_morlet(example['neutLongCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
tfr_neutLongCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))

disMinusNeut_longCue=tfr_disLongCue-tfr_neutLongCue
#disMinusNeut_longCue.plot(vmin=-7,vmax=7,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
#disMinusNeut_longCue.plot(vmin=-7,vmax=7,picks=['F1','Fz','F2','FC1','FCz','FC2'])

# %% [markdown]
# # Plotting ea sub

# %% [markdown]
# ## Contrast ([distractor cue, long SOA] - [neutral cue, long SOA])
# ### Timing of the epochs: -500 is the onset of the grey placeholders, 0 is the onset of the colored cues for either 100ms or 1000ms

# %%
for s in list_subs:
    print('\n\n\n')
    thisSub=preproc_cue_eps[s]
    print('PLOTTING SUB %s' %s)
    tfr_disLongCue=mne.time_frequency.tfr_morlet(thisSub['disLongCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutLongCue=mne.time_frequency.tfr_morlet(thisSub['neutLongCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutLongCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    tfr_disLongCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    
    disMinusNeut_longCue=tfr_disLongCue-tfr_neutLongCue
    print('Posterior Chs:')
    disMinusNeut_longCue.plot(vmin=-7,vmax=7,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
    print('Frontal Chs:')
    disMinusNeut_longCue.plot(vmin=-7,vmax=7,picks=['F1','Fz','F2','FC1','FCz','FC2'])

# %% [markdown]
# ## [ Target, Long SOA Cue] - [neutral, long SOA cue]

# %%
for s in list_subs:
    print('\n\n\n')
    thisSub=preproc_cue_eps[s]
    print('PLOTTING SUB %s' %s)
    tfr_tarLongCue=mne.time_frequency.tfr_morlet(thisSub['tarLongCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutLongCue=mne.time_frequency.tfr_morlet(thisSub['neutLongCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutLongCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    tfr_tarLongCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    
    tarMinusNeut_longCue=tfr_tarLongCue-tfr_neutLongCue
    print('Posterior Chs:')
    tarMinusNeut_longCue.plot(vmin=-7,vmax=7,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
    print('Frontal Chs:')
    tarMinusNeut_longCue.plot(vmin=-7,vmax=7,picks=['F1','Fz','F2','FC1','FCz','FC2'])

# %% [markdown]
# ## [Dis, short SOA cue] - [neutral, short SOA cue]

# %%
for s in list_subs:
    print('\n\n\n')
    thisSub=preproc_cue_eps[s]
    print('PLOTTING SUB %s' %s)
    tfr_disShortCue=mne.time_frequency.tfr_morlet(thisSub['disShortCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutShortCue=mne.time_frequency.tfr_morlet(thisSub['neutShortCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutShortCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    tfr_disShortCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    
    disMinusNeut_shortCue=tfr_disShortCue-tfr_neutShortCue
    print('Posterior Chs:')
    disMinusNeut_shortCue.plot(vmin=-7,vmax=7,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
    print('Frontal Chs:')
    disMinusNeut_shortCue.plot(vmin=-7,vmax=7,picks=['F1','Fz','F2','FC1','FCz','FC2'])

# %% [markdown]
# ## [Tar short SOA] - [neut short SOA]

# %%
for s in list_subs:
    print('\n\n\n')
    thisSub=preproc_cue_eps[s]
    print('PLOTTING SUB %s' %s)
    tfr_tarShortCue=mne.time_frequency.tfr_morlet(thisSub['tarShortCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutShortCue=mne.time_frequency.tfr_morlet(thisSub['neutShortCue_trig'],freqs=freqs,n_cycles=n_cycles,average=True,
                                             use_fft=True,return_itc=False, decim=2, n_jobs=1)
    tfr_neutShortCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    tfr_tarShortCue.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    
    tarMinusNeut_shortCue=tfr_tarShortCue-tfr_neutShortCue
    print('Posterior Chs:')
    tarMinusNeut_shortCue.plot(vmin=-7,vmax=7,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
    print('Frontal Chs:')
    tarMinusNeut_shortCue.plot(vmin=-7,vmax=7,picks=['F1','Fz','F2','FC1','FCz','FC2'])

# %%
preproc_cue_eps
# Out:
# {'224': <EpochsFIF  |   660 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~386.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 110
#   'disShortCue_trig': 110
#   'neutLongCue_trig': 110
#   'neutShortCue_trig': 110
#   'tarLongCue_trig': 110
#   'tarShortCue_trig': 110>,
#  '214': <EpochsFIF  |   592 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~346.3 MB, data loaded, with metadata,
#   'disLongCue_trig': 99
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 98
#   'tarLongCue_trig': 98
#   'tarShortCue_trig': 99>,
#  '211': <EpochsFIF  |   590 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~345.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 97
#   'disShortCue_trig': 98
#   'neutLongCue_trig': 99
#   'neutShortCue_trig': 99
#   'tarLongCue_trig': 99
#   'tarShortCue_trig': 98>,
#  '206': <EpochsFIF  |   597 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~349.2 MB, data loaded, with metadata,
#   'disLongCue_trig': 100
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 99
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 100>,
#  '225': <EpochsFIF  |   600 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~351.0 MB, data loaded, with metadata,
#   'disLongCue_trig': 100
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 100
#   'neutShortCue_trig': 100
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 100>,
#  '226': <EpochsFIF  |   598 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~349.8 MB, data loaded, with metadata,
#   'disLongCue_trig': 99
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 100
#   'neutShortCue_trig': 100
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 99>,
#  '233': <EpochsFIF  |   596 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~348.6 MB, data loaded, with metadata,
#   'disLongCue_trig': 98
#   'disShortCue_trig': 100
#   'neutLongCue_trig': 100
#   'neutShortCue_trig': 99
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 99>,
#  '223': <EpochsFIF  |   589 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~344.5 MB, data loaded, with metadata,
#   'disLongCue_trig': 100
#   'disShortCue_trig': 98
#   'neutLongCue_trig': 97
#   'neutShortCue_trig': 96
#   'tarLongCue_trig': 100
#   'tarShortCue_trig': 98>,
#  '197': <EpochsFIF  |   578 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~338.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 96
#   'disShortCue_trig': 98
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 93
#   'tarLongCue_trig': 99
#   'tarShortCue_trig': 94>,
#  '228': <EpochsFIF  |   578 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~338.1 MB, data loaded, with metadata,
#   'disLongCue_trig': 98
#   'disShortCue_trig': 96
#   'neutLongCue_trig': 98
#   'neutShortCue_trig': 98
#   'tarLongCue_trig': 94
#   'tarShortCue_trig': 94>}

# %% [markdown]
# # Avg over subs

# %%
all_conds=['tarShortCue_trig','disShortCue_trig','neutShortCue_trig',
           'tarLongCue_trig','disLongCue_trig','neutLongCue_trig']
all_subs_Cues={}


for cond in all_conds:  
    skeleton_obj=mne.time_frequency.tfr_morlet(preproc_cue_eps['228'][cond],freqs=freqs,n_cycles=n_cycles,
                                               average=True,use_fft=True,return_itc=False, decim=2, n_jobs=1)
    thisCond_allSubsDat=[]
    for s in list_subs:
        #print('\n\n\n')
        thisSub=preproc_cue_eps[s]
        print('extracting sub %s' %s)
        print(thisSub.get_data().shape)
        subDat=mne.time_frequency.tfr_morlet(thisSub[cond],freqs=freqs,n_cycles=n_cycles,average=True,
                                                 use_fft=True,return_itc=False, decim=2, n_jobs=1)
        print(subDat.data.shape)
        thisCond_allSubsDat.append(subDat.data)

    all_subs_thisCond=np.stack(thisCond_allSubsDat)
    print(all_subs_thisCond.shape)
    all_subs_thisCond=all_subs_thisCond.mean(axis=0)
    skeleton_obj.data=all_subs_thisCond
    
    skeleton_obj.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
    all_subs_Cues[cond]=skeleton_obj
# Out:
# extracting sub 224
# (660, 65, 1179)
# (64, 19, 590)
# extracting sub 214
# (592, 65, 1179)
# (64, 19, 590)
# extracting sub 211
# (590, 65, 1179)
# (64, 19, 590)
# extracting sub 206
# (597, 65, 1179)
# (64, 19, 590)
# extracting sub 225
# (600, 65, 1179)
# (64, 19, 590)
# extracting sub 226
# (598, 65, 1179)
# (64, 19, 590)
# extracting sub 233
# (596, 65, 1179)
# (64, 19, 590)
# extracting sub 223
# (589, 65, 1179)
# (64, 19, 590)
# extracting sub 197
# (578, 65, 1179)
# (64, 19, 590)
# extracting sub 228
# (578, 65, 1179)
# (64, 19, 590)
# (10, 64, 19, 590)
# Applying baseline correction (mode: zscore)
# extracting sub 224
# (660, 65, 1179)
# (64, 19, 590)
# extracting sub 214
# (592, 65, 1179)
# (64, 19, 590)
# extracting sub 211
# (590, 65, 1179)
# (64, 19, 590)
# extracting sub 206
# (597, 65, 1179)
# (64, 19, 590)
# extracting sub 225
# (600, 65, 1179)
# (64, 19, 590)
# extracting sub 226
# (598, 65, 1179)
# (64, 19, 590)
# extracting sub 233
# (596, 65, 1179)
# (64, 19, 590)
# extracting sub 223
# (589, 65, 1179)
# (64, 19, 590)
# extracting sub 197
# (578, 65, 1179)
# (64, 19, 590)
# extracting sub 228
# (578, 65, 1179)
# (64, 19, 590)
# (10, 64, 19, 590)
# Applying baseline correction (mode: zscore)
# extracting sub 224
# (660, 65, 1179)
# (64, 19, 590)
# extracting sub 214
# (592, 65, 1179)
# (64, 19, 590)
# extracting sub 211
# (590, 65, 1179)
# (64, 19, 590)
# extracting sub 206
# (597, 65, 1179)
# (64, 19, 590)
# extracting sub 225
# (600, 65, 1179)
# (64, 19, 590)
# extracting sub 226
# (598, 65, 1179)
# (64, 19, 590)
# extracting sub 233
# (596, 65, 1179)
# (64, 19, 590)
# extracting sub 223
# (589, 65, 1179)
# (64, 19, 590)
# extracting sub 197
# (578, 65, 1179)
# (64, 19, 590)
# extracting sub 228
# (578, 65, 1179)
# (64, 19, 590)
# (10, 64, 19, 590)
# Applying baseline correction (mode: zscore)
# extracting sub 224
# (660, 65, 1179)
# (64, 19, 590)
# extracting sub 214
# (592, 65, 1179)
# (64, 19, 590)
# extracting sub 211
# (590, 65, 1179)
# (64, 19, 590)
# extracting sub 206
# (597, 65, 1179)
# (64, 19, 590)
# extracting sub 225
# (600, 65, 1179)
# (64, 19, 590)
# extracting sub 226
# (598, 65, 1179)
# (64, 19, 590)
# extracting sub 233
# (596, 65, 1179)
# (64, 19, 590)
# extracting sub 223
# (589, 65, 1179)
# (64, 19, 590)
# extracting sub 197
# (578, 65, 1179)
# (64, 19, 590)
# extracting sub 228
# (578, 65, 1179)
# (64, 19, 590)
# (10, 64, 19, 590)
# Applying baseline correction (mode: zscore)
# extracting sub 224
# (660, 65, 1179)
# (64, 19, 590)
# extracting sub 214
# (592, 65, 1179)
# (64, 19, 590)
# extracting sub 211
# (590, 65, 1179)
# (64, 19, 590)
# extracting sub 206
# (597, 65, 1179)
# (64, 19, 590)
# extracting sub 225
# (600, 65, 1179)
# (64, 19, 590)
# extracting sub 226
# (598, 65, 1179)
# (64, 19, 590)
# extracting sub 233
# (596, 65, 1179)
# (64, 19, 590)
# extracting sub 223
# (589, 65, 1179)
# (64, 19, 590)
# extracting sub 197
# (578, 65, 1179)
# (64, 19, 590)
# extracting sub 228
# (578, 65, 1179)
# (64, 19, 590)
# (10, 64, 19, 590)
# Applying baseline correction (mode: zscore)
# extracting sub 224
# (660, 65, 1179)
# (64, 19, 590)
# extracting sub 214
# (592, 65, 1179)
# (64, 19, 590)
# extracting sub 211
# (590, 65, 1179)
# (64, 19, 590)
# extracting sub 206
# (597, 65, 1179)
# (64, 19, 590)
# extracting sub 225
# (600, 65, 1179)
# (64, 19, 590)
# extracting sub 226
# (598, 65, 1179)
# (64, 19, 590)
# extracting sub 233
# (596, 65, 1179)
# (64, 19, 590)
# extracting sub 223
# (589, 65, 1179)
# (64, 19, 590)
# extracting sub 197
# (578, 65, 1179)
# (64, 19, 590)
# extracting sub 228
# (578, 65, 1179)
# (64, 19, 590)
# (10, 64, 19, 590)
# Applying baseline correction (mode: zscore)

# %%
a=mne.time_frequency.tfr_morlet(preproc_cue_eps['225'][cond],freqs=freqs,n_cycles=n_cycles,average=True,
                                                 use_fft=True,return_itc=False, decim=2, n_jobs=1)
b=mne.time_frequency.tfr_morlet(preproc_cue_eps['228'][cond],freqs=freqs,n_cycles=n_cycles,average=True,
                                                 use_fft=True,return_itc=False, decim=2, n_jobs=1)

# %%
preproc_cue_eps['228'][cond]
# Out:
# <EpochsFIF  |   94 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~55.1 MB, data loaded, with metadata,
#  'tarLongCue_trig': 94>

# %%
cond
# Out:
# 'tarLongCue_trig'

# %%
b.data.shape
# Out:
# (64, 19, 590)

# %% [markdown]
# ## target Long SOA - neutral Long SOA

# %%
tarMinusneut_Long=all_subs_Cues['tarLongCue_trig']-all_subs_Cues['neutLongCue_trig']

print('Posterior Chs:')
tarMinusneut_Long.plot(vmin=-7,vmax=7,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
print('Frontal Chs:')
tarMinusneut_Long.plot(vmin=-7,vmax=7,picks=['F1','Fz','F2','FC1','FCz','FC2'])

print('Plotting theta 0-200msec')
tarMinusneut_Long.plot_topomap(fmin=4,fmax=8,tmin=0,tmax=0.2,vmin=-6,vmax=6)
print('Plotting theta 200-400msec')
tarMinusneut_Long.plot_topomap(fmin=4,fmax=8,tmin=0.2,tmax=0.4,vmin=-6,vmax=6)
print('Plotting theta 400-800msec')
tarMinusneut_Long.plot_topomap(fmin=4,fmax=8,tmin=0.4,tmax=0.8,vmin=-6,vmax=6)
print('Plotting theta 800-1000msec')
tarMinusneut_Long.plot_topomap(fmin=4,fmax=8,tmin=0.8,tmax=1,vmin=-6,vmax=6)

print('\n\n\n______________________________________-')
print('Plotting Alpha band')
tarMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)
tarMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
tarMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2)
tarMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2)
# Out:
# Posterior Chs:
# No baseline correction applied
# Frontal Chs:
# No baseline correction applied
# Plotting theta 0-200msec
# No baseline correction applied
# Plotting theta 200-400msec
# No baseline correction applied
# Plotting theta 400-800msec
# No baseline correction applied
# Plotting theta 800-1000msec
# No baseline correction applied
# ______________________________________-
# Plotting Alpha band
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %% [markdown]
# ## dis Long SOA - neutral Long SOA

# %%
disMinusneut_Long=all_subs_Cues['disLongCue_trig']-all_subs_Cues['neutLongCue_trig']

print('Posterior Chs:')
disMinusneut_Long.plot(vmin=-6,vmax=6,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
print('Frontal Chs:')
disMinusneut_Long.plot(vmin=-6,vmax=6,picks=['F1','Fz','F2','FC1','FCz','FC2'])

print('Plotting Alpha band')
disMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)
disMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
disMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2)
disMinusneut_Long.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2)
# Out:
# Posterior Chs:
# No baseline correction applied
# Frontal Chs:
# No baseline correction applied
# Plotting Alpha band
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %% [markdown]
# ## tar Short SOA - neutral Short SOA

# %%
tarMinusneut_Short=all_subs_Cues['tarShortCue_trig']-all_subs_Cues['neutShortCue_trig']

print('Posterior Chs:')
tarMinusneut_Short.plot(vmin=-6,vmax=6,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
print('Frontal Chs:')
tarMinusneut_Short.plot(vmin=-6,vmax=6,picks=['F1','Fz','F2','FC1','FCz','FC2'])

print('Plotting theta 0-200msec')
tarMinusneut_Short.plot_topomap(fmin=4,fmax=8,tmin=0,tmax=0.2,vmin=-6,vmax=6)
print('Plotting theta 200-400msec')
tarMinusneut_Short.plot_topomap(fmin=4,fmax=8,tmin=0.2,tmax=0.4,vmin=-6,vmax=6)
print('Plotting theta 400-800msec')
tarMinusneut_Short.plot_topomap(fmin=4,fmax=8,tmin=0.4,tmax=0.8,vmin=-6,vmax=6)
print('Plotting theta 800-1000msec')
tarMinusneut_Short.plot_topomap(fmin=4,fmax=8,tmin=0.8,tmax=1,vmin=-6,vmax=6)
# Out:
# Posterior Chs:
# No baseline correction applied
# Frontal Chs:
# No baseline correction applied
# Plotting theta 0-200msec
# No baseline correction applied
# Plotting theta 200-400msec
# No baseline correction applied
# Plotting theta 400-800msec
# No baseline correction applied
# Plotting theta 800-1000msec
# No baseline correction applied

# %% [markdown]
# ## dis Short SOA - neutral Short SOA

# %%
disMinusneut_Short=all_subs_Cues['disShortCue_trig']-all_subs_Cues['neutShortCue_trig']

print('Posterior Chs:')
disMinusneut_Short.plot(vmin=-5,vmax=5,picks=['P1','Pz','P2','P3','P4','PO3','PO4','POz'])
print('Frontal Chs:')
disMinusneut_Short.plot(vmin=-5,vmax=5,picks=['F1','Fz','F2','FC1','FCz','FC2'])


print('Plotting Alpha band')
disMinusneut_Short.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)
disMinusneut_Short.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
disMinusneut_Short.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2)
disMinusneut_Short.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2)
# Out:
# Posterior Chs:
# No baseline correction applied
# Frontal Chs:
# No baseline correction applied
# Plotting Alpha band
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
