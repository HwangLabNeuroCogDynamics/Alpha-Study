# %%
import pandas as pd
import mne
import os
import numpy as np
from mne.time_frequency import tfr_morlet
import ast

# %%
ROOT_preproc='/data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/'
list_subs=os.listdir(ROOT_preproc)
print(len(list_subs))
list_subs.remove('206') # this sub is causing problems for the subject averaged neutral cues
list_subs.remove('239')
print(len(list_subs))
preproc_cue_eps={}
preproc_probe_eps={}
for s in list_subs:
    cue=mne.read_epochs(ROOT_preproc+s+'/'+'cue-epo.fif')
    probe=mne.read_epochs(ROOT_preproc+s+'/'+'probe events-epo.fif')
    preproc_cue_eps[s]=cue
    preproc_probe_eps[s]=probe
# Out:
# 16
# 14
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/224/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 660 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/224/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 660 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/214/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 592 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/214/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 595 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 15 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/211/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 590 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 38 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/211/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 582 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 38 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/244/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 599 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/244/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 597 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/225/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 600 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/225/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 595 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/231/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 571 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/231/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 585 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/241/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 567 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/241/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 575 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/226/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 598 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/226/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 592 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/233/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 596 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/233/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 593 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/240/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 599 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/240/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 599 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/223/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 589 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/223/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 583 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/197/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 578 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/197/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 577 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/228/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 578 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 36 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/228/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 548 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 38 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/237/cue-epo.fif ...
#     Found the data of interest:
#         t =   -1300.78 ...    1000.00 ms
#         0 CTF compensation matrices available
# 598 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated
# Reading /data/backed_up/shared/AlphaStudy_data/placeholders/preproc_EEG_matchingBrad/237/probe events-epo.fif ...
#     Found the data of interest:
#         t =       0.00 ...    5400.39 ms
#         0 CTF compensation matrices available
# 596 matching events found
# Applying baseline correction (mode: mean)
# Adding metadata with 37 columns
# 0 projection items activated

# %%
preproc_cue_eps['214'].metadata['block'].iloc[0]==1
# Out:
# True

# %%
len(list_subs)
# Out:
# 14

# %%
list_subs
# Out:
# ['224',
#  '214',
#  '211',
#  '244',
#  '225',
#  '231',
#  '241',
#  '226',
#  '233',
#  '240',
#  '223',
#  '197',
#  '228',
#  '237']

# %%
right_stim=['1','3','5']
center_stim=['6','12']
left_stim=['7','9','11']

# %%
# We have to loop through each subject, each condition, 
# and find every trial that is *not* in the L, R, or center,
# and drop those tirals from 3 copies of the original epochs to get three
# copies that are only L, R, or Center trials

conditions=['tarShortCue_trig','disShortCue_trig',
           'tarLongCue_trig','disLongCue_trig']#,'neutShortCue_trig','neutLongCue_trig']
preprocCues_LeftH={}
preprocCues_RightH={}
preprocCues_Neutrals={}

for sub in preproc_cue_eps.keys():
    
    preprocCues_LeftH[sub]={}
    preprocCues_RightH[sub]={}
    preprocCues_Neutrals[sub]={}
    
    # load cue_epochs for this sub
    cue_eps=preproc_cue_eps[sub]
    
    # loop thru conditions
    for cond in conditions:
        epsForThisCond=cue_eps[cond]
                    
        # set up empty lists to be populated with trials that are NOT L/R/center
        not_right_end=[]
        not_right_begin=[]
        not_left_end=[]
        not_left_begin=[]
        # will populate w bools where True== drop this trial

        # loop thru each trial, and check out the metadata
        for trial_n in range(len(epsForThisCond)):
            this_trial=epsForThisCond[trial_n]

            assert this_trial.metadata['trial_type'].iloc[0] in cond            
            # grab out the behav data of this trial
            this_trial_BeginOrEnd=this_trial.metadata['block'].iloc[0]
            if this_trial_BeginOrEnd <6:
                trial_timing='FirstFive'
            elif this_trial_BeginOrEnd >=6:
                trial_timing='LastFive'
            this_trial_StimLoc=this_trial.metadata['tar,dis stim_loc'].iloc[0]
            this_trial_StimLoc=ast.literal_eval(this_trial_StimLoc) # turn it into a literal tuple

            # identify the condition of interest and pull out that stim loc
            if 'tar' in cond:
                thisClockPos=this_trial_StimLoc[0] 
                # if its the target that was the color singleton, we care about which
                                        # hemisphere that was in
            elif 'dis' in cond:
                thisClockPos=this_trial_StimLoc[1]

            # if the the clock pos is on the right side of the screen, 
                # then we want to document as not-not right, not left, and not center
            if thisClockPos in right_stim:
                if trial_timing=='FirstFive':
                    not_right_begin.append(False)
                    not_left_begin.append(True)
                    not_right_end.append(True)
                    not_left_end.append(True)
                elif trial_timing=='LastFive':
                    not_right_begin.append(True)
                    not_left_begin.append(True)
                    not_right_end.append(False)
                    not_left_end.append(True)
            elif thisClockPos in left_stim:
                if trial_timing=='FirstFive':
                    not_right_begin.append(True)
                    not_left_begin.append(False)
                    not_right_end.append(True)
                    not_left_end.append(True)
                elif trial_timing=='LastFive':
                    not_right_begin.append(True)
                    not_left_begin.append(True)
                    not_right_end.append(True)
                    not_left_end.append(False)
            else:
                not_right_end.append(True)
                not_left_end.append(True)
                not_right_begin.append(True)
                not_left_begin.append(True)

        print(len(not_right_end),len(not_left_end),len(not_left_begin),len(not_right_begin),len(epsForThisCond))
        assert len(not_right_end) == len(not_left_end)==len(not_right_begin)==len(not_left_begin) == len(epsForThisCond)

        # make three copies of the original epochs for this condition
        all_Rights_firstFive=epsForThisCond.copy()
        all_Lefts_firstFive=epsForThisCond.copy()
        all_Rights_lastFive=epsForThisCond.copy()
        all_Lefts_lastFive=epsForThisCond.copy()

        # then drop all of the epochs that are "True" in not being on the side of the screen we want
        all_Rights_firstFive.drop(indices=np.asarray(not_right_begin),reason='Dropping all left and centers')
        all_Lefts_firstFive.drop(indices=np.asarray(not_left_begin),reason='Dropping all right and centers')
        all_Rights_lastFive.drop(indices=np.asarray(not_right_end),reason='Dropping all left and centers')
        all_Lefts_lastFive.drop(indices=np.asarray(not_left_end),reason='Dropping all right and centers')



        # now put it into a dict
        preprocCues_LeftH[sub][cond]={}
        preprocCues_LeftH[sub][cond]['FirstFive']=all_Lefts_firstFive
        preprocCues_LeftH[sub][cond]['LastFive']=all_Lefts_lastFive
        preprocCues_RightH[sub][cond]={}
        preprocCues_RightH[sub][cond]['FirstFive']=all_Rights_firstFive
        preprocCues_RightH[sub][cond]['LastFive']=all_Rights_lastFive
# Out:
# 110 110 110 110 110
# Dropped 87 epochs
# Dropped 92 epochs
# Dropped 85 epochs
# Dropped 86 epochs
# 110 110 110 110 110
# Dropped 88 epochs
# Dropped 97 epochs
# Dropped 90 epochs
# Dropped 87 epochs
# 110 110 110 110 110
# Dropped 90 epochs
# Dropped 95 epochs
# Dropped 85 epochs
# Dropped 90 epochs
# 110 110 110 110 110
# Dropped 98 epochs
# Dropped 85 epochs
# Dropped 89 epochs
# Dropped 84 epochs
# 99 99 99 99 99
# Dropped 81 epochs
# Dropped 82 epochs
# Dropped 81 epochs
# Dropped 82 epochs
# 100 100 100 100 100
# Dropped 77 epochs
# Dropped 87 epochs
# Dropped 82 epochs
# Dropped 79 epochs
# 98 98 98 98 98
# Dropped 84 epochs
# Dropped 74 epochs
# Dropped 79 epochs
# Dropped 82 epochs
# 99 99 99 99 99
# Dropped 78 epochs
# Dropped 81 epochs
# Dropped 85 epochs
# Dropped 71 epochs
# 98 98 98 98 98
# Dropped 84 epochs
# Dropped 75 epochs
# Dropped 78 epochs
# Dropped 78 epochs
# 98 98 98 98 98
# Dropped 80 epochs
# Dropped 79 epochs
# Dropped 78 epochs
# Dropped 79 epochs
# 99 99 99 99 99
# Dropped 83 epochs
# Dropped 77 epochs
# Dropped 81 epochs
# Dropped 82 epochs
# 97 97 97 97 97
# Dropped 81 epochs
# Dropped 81 epochs
# Dropped 83 epochs
# Dropped 73 epochs
# 100 100 100 100 100
# Dropped 83 epochs
# Dropped 80 epochs
# Dropped 82 epochs
# Dropped 83 epochs
# 100 100 100 100 100
# Dropped 78 epochs
# Dropped 82 epochs
# Dropped 81 epochs
# Dropped 80 epochs
# 99 99 99 99 99
# Dropped 83 epochs
# Dropped 75 epochs
# Dropped 85 epochs
# Dropped 77 epochs
# 100 100 100 100 100
# Dropped 85 epochs
# Dropped 76 epochs
# Dropped 79 epochs
# Dropped 80 epochs
# 100 100 100 100 100
# Dropped 85 epochs
# Dropped 77 epochs
# Dropped 83 epochs
# Dropped 85 epochs
# 100 100 100 100 100
# Dropped 81 epochs
# Dropped 77 epochs
# Dropped 79 epochs
# Dropped 85 epochs
# 100 100 100 100 100
# Dropped 86 epochs
# Dropped 75 epochs
# Dropped 76 epochs
# Dropped 85 epochs
# 100 100 100 100 100
# Dropped 77 epochs
# Dropped 82 epochs
# Dropped 78 epochs
# Dropped 87 epochs
# 94 94 94 94 94
# Dropped 76 epochs
# Dropped 76 epochs
# Dropped 75 epochs
# Dropped 76 epochs
# 97 97 97 97 97
# Dropped 77 epochs
# Dropped 83 epochs
# Dropped 82 epochs
# Dropped 74 epochs
# 96 96 96 96 96
# Dropped 77 epochs
# Dropped 76 epochs
# Dropped 79 epochs
# Dropped 75 epochs
# 97 97 97 97 97
# Dropped 78 epochs
# Dropped 80 epochs
# Dropped 82 epochs
# Dropped 73 epochs
# 96 96 96 96 96
# Dropped 75 epochs
# Dropped 78 epochs
# Dropped 76 epochs
# Dropped 75 epochs
# 96 96 96 96 96
# Dropped 81 epochs
# Dropped 76 epochs
# Dropped 79 epochs
# Dropped 75 epochs
# 98 98 98 98 98
# Dropped 81 epochs
# Dropped 76 epochs
# Dropped 72 epochs
# Dropped 84 epochs
# 92 92 92 92 92
# Dropped 79 epochs
# Dropped 72 epochs
# Dropped 77 epochs
# Dropped 73 epochs
# 99 99 99 99 99
# Dropped 87 epochs
# Dropped 77 epochs
# Dropped 79 epochs
# Dropped 82 epochs
# 100 100 100 100 100
# Dropped 76 epochs
# Dropped 84 epochs
# Dropped 81 epochs
# Dropped 82 epochs
# 100 100 100 100 100
# Dropped 86 epochs
# Dropped 82 epochs
# Dropped 81 epochs
# Dropped 80 epochs
# 99 99 99 99 99
# Dropped 81 epochs
# Dropped 77 epochs
# Dropped 83 epochs
# Dropped 81 epochs
# 99 99 99 99 99
# Dropped 82 epochs
# Dropped 80 epochs
# Dropped 81 epochs
# Dropped 79 epochs
# 100 100 100 100 100
# Dropped 84 epochs
# Dropped 80 epochs
# Dropped 79 epochs
# Dropped 82 epochs
# 100 100 100 100 100
# Dropped 82 epochs
# Dropped 76 epochs
# Dropped 88 epochs
# Dropped 72 epochs
# 98 98 98 98 98
# Dropped 76 epochs
# Dropped 80 epochs
# Dropped 77 epochs
# Dropped 84 epochs
# 100 100 100 100 100
# Dropped 83 epochs
# Dropped 78 epochs
# Dropped 84 epochs
# Dropped 78 epochs
# 100 100 100 100 100
# Dropped 84 epochs
# Dropped 80 epochs
# Dropped 81 epochs
# Dropped 83 epochs
# 99 99 99 99 99
# Dropped 87 epochs
# Dropped 73 epochs
# Dropped 77 epochs
# Dropped 84 epochs
# 100 100 100 100 100
# Dropped 86 epochs
# Dropped 78 epochs
# Dropped 84 epochs
# Dropped 80 epochs
# 98 98 98 98 98
# Dropped 77 epochs
# Dropped 75 epochs
# Dropped 81 epochs
# Dropped 77 epochs
# 98 98 98 98 98
# Dropped 85 epochs
# Dropped 78 epochs
# Dropped 77 epochs
# Dropped 84 epochs
# 100 100 100 100 100
# Dropped 76 epochs
# Dropped 84 epochs
# Dropped 83 epochs
# Dropped 76 epochs
# 100 100 100 100 100
# Dropped 78 epochs
# Dropped 89 epochs
# Dropped 79 epochs
# Dropped 83 epochs
# 94 94 94 94 94
# Dropped 75 epochs
# Dropped 75 epochs
# Dropped 82 epochs
# Dropped 74 epochs
# 98 98 98 98 98
# Dropped 71 epochs
# Dropped 82 epochs
# Dropped 80 epochs
# Dropped 86 epochs
# 99 99 99 99 99
# Dropped 78 epochs
# Dropped 75 epochs
# Dropped 91 epochs
# Dropped 76 epochs
# 96 96 96 96 96
# Dropped 78 epochs
# Dropped 76 epochs
# Dropped 74 epochs
# Dropped 86 epochs
# 94 94 94 94 94
# Dropped 76 epochs
# Dropped 80 epochs
# Dropped 77 epochs
# Dropped 77 epochs
# 96 96 96 96 96
# Dropped 81 epochs
# Dropped 72 epochs
# Dropped 80 epochs
# Dropped 80 epochs
# 94 94 94 94 94
# Dropped 78 epochs
# Dropped 76 epochs
# Dropped 72 epochs
# Dropped 76 epochs
# 98 98 98 98 98
# Dropped 78 epochs
# Dropped 80 epochs
# Dropped 76 epochs
# Dropped 86 epochs
# 100 100 100 100 100
# Dropped 81 epochs
# Dropped 81 epochs
# Dropped 82 epochs
# Dropped 80 epochs
# 100 100 100 100 100
# Dropped 82 epochs
# Dropped 80 epochs
# Dropped 82 epochs
# Dropped 81 epochs
# 99 99 99 99 99
# Dropped 76 epochs
# Dropped 82 epochs
# Dropped 81 epochs
# Dropped 80 epochs
# 100 100 100 100 100
# Dropped 76 epochs
# Dropped 78 epochs
# Dropped 81 epochs
# Dropped 81 epochs

# %%
preprocCues_LeftH['224']['tarShortCue_trig']['FirstFive'].metadata
# Out:
#      tar_color dis_color    SOA  block  trialNum trial_type corrResp subResp  \
# 38        blue      pink  short      1         7        tar        p       q
# 288       blue      pink  short      1        57        tar        q       q
# 360       blue      pink  short      2        11        tar        p    None
# 365       blue      pink  short      2        12        tar        p    None
# 445       blue      pink  short      2        28        tar        q       q
# 505       blue      pink  short      2        40        tar        p    None
# 642       blue      pink  short      3         7        tar        p       p
# 712       blue      pink  short      3        21        tar        p       p
# 732       blue      pink  short      3        25        tar        q       q
# 969       blue      pink  short      4        12        tar        p       p
# 1039      blue      pink  short      4        26        tar        q    None
# 1134      blue      pink  short      4        45        tar        q       q
# 1169      blue      pink  short      4        52        tar        p       p
# 1296      blue      pink  short      5        17        tar        p       p
# 1331      blue      pink  short      5        24        tar        q       q
# 1421      blue      pink  short      5        42        tar        p       p
# 1436      blue      pink  short      5        45        tar        p       p
# 1486      blue      pink  short      5        55        tar        q       q
#
#       trialCorr?        RT tar,dis stim_loc  ITI  \
# 38           0.0  1.465627      ('9', '11')  4.4
# 288          1.0  1.165644       ('7', '6')  4.5
# 360          NaN       NaN      ('11', '6')  4.3
# 365          NaN       NaN       ('7', '5')  4.1
# 445          1.0  1.115646       ('9', '6')  4.3
# 505          NaN       NaN       ('9', '6')  3.5
# 642          1.0  1.382300       ('9', '1')  4.4
# 712          1.0  1.298969       ('7', '3')  3.6
# 732          1.0  0.999016       ('9', '6')  3.5
# 969          1.0  0.932361      ('9', '11')  4.2
# 1039         NaN       NaN       ('7', '5')  4.2
# 1134         1.0  0.782294      ('11', '9')  4.5
# 1169         1.0  0.932329       ('7', '3')  4.5
# 1296         1.0  0.765658       ('7', '3')  4.4
# 1331         1.0  0.965661       ('9', '1')  4.5
# 1421         1.0  1.498962      ('11', '3')  3.8
# 1436         1.0  1.215601       ('9', '3')  3.5
# 1486         1.0  1.132280       ('7', '5')  3.6
#
#                                           Tar,Dis,Other      trial_trigs  \
# 38    ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 288    ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 360    ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 365    ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 445    ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 505   ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 642   ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 712   ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 732    ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 969    ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 1039   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 1134   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 1169   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 1296  ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 1331  ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 1421   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 1436   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 1486  ('blue_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
#
#                                                triggers
# 38    ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 288   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 360   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 365   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 445   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 505   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 642   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 712   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 732   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 969   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1039  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1134  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1169  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1296  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1331  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1421  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1436  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1486  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...

# %%
preproc_cue_eps['224']
# Out:
# <EpochsFIF  |   660 events (all good), -1.30078 - 1 sec, baseline [-1.30078, -0.3], ~386.1 MB, data loaded, with metadata,
#  'disLongCue_trig': 110
#  'disShortCue_trig': 110
#  'neutLongCue_trig': 110
#  'neutShortCue_trig': 110
#  'tarLongCue_trig': 110
#  'tarShortCue_trig': 110>

# %%
ex_neut=preproc_cue_eps['224']['neutLongCue_trig']
exNeut_firstBlocks=ex_neut[ex_neut.metadata['block'] < 6]
exNeut_firstBlocks.metadata
# Out:
#      tar_color dis_color   SOA  block  trialNum trial_type corrResp subResp  \
# 3         blue      pink  long      1         0       neut        q    None
# 33        blue      pink  long      1         6       neut        q    None
# 73        blue      pink  long      1        14       neut        q       p
# 128       blue      pink  long      1        25       neut        q       q
# 133       blue      pink  long      1        26       neut        p       p
# 158       blue      pink  long      1        31       neut        p       p
# 188       blue      pink  long      1        37       neut        q    None
# 218       blue      pink  long      1        43       neut        p       p
# 228       blue      pink  long      1        45       neut        q       q
# 298       blue      pink  long      1        59       neut        p    None
# 325       blue      pink  long      2         4       neut        p    None
# 355       blue      pink  long      2        10       neut        q    None
# 390       blue      pink  long      2        17       neut        p    None
# 440       blue      pink  long      2        27       neut        p    None
# 450       blue      pink  long      2        29       neut        q    None
# 480       blue      pink  long      2        35       neut        q       q
# 515       blue      pink  long      2        42       neut        p    None
# 550       blue      pink  long      2        49       neut        q       q
# 585       blue      pink  long      2        56       neut        q       q
# 595       blue      pink  long      2        58       neut        p    None
# 647       blue      pink  long      3         8       neut        p       p
# 652       blue      pink  long      3         9       neut        p       p
# 677       blue      pink  long      3        14       neut        p       p
# 727       blue      pink  long      3        24       neut        p       p
# 747       blue      pink  long      3        28       neut        p       p
# 752       blue      pink  long      3        29       neut        p    None
# 762       blue      pink  long      3        31       neut        p       p
# 867       blue      pink  long      3        52       neut        p       p
# 882       blue      pink  long      3        55       neut        p       p
# 887       blue      pink  long      3        56       neut        q       q
# 919       blue      pink  long      4         2       neut        p       p
# 924       blue      pink  long      4         3       neut        p       p
# 944       blue      pink  long      4         7       neut        p    None
# 954       blue      pink  long      4         9       neut        p       p
# 964       blue      pink  long      4        11       neut        q       q
# 994       blue      pink  long      4        17       neut        q       q
# 1014      blue      pink  long      4        21       neut        p       p
# 1064      blue      pink  long      4        31       neut        p       p
# 1094      blue      pink  long      4        37       neut        q       q
# 1174      blue      pink  long      4        53       neut        p       p
# 1211      blue      pink  long      5         0       neut        p       p
# 1216      blue      pink  long      5         1       neut        p       p
# 1281      blue      pink  long      5        14       neut        q       q
# 1316      blue      pink  long      5        21       neut        p       p
# 1351      blue      pink  long      5        28       neut        q    None
# 1366      blue      pink  long      5        31       neut        q    None
# 1391      blue      pink  long      5        36       neut        q       q
# 1406      blue      pink  long      5        39       neut        q       q
# 1431      blue      pink  long      5        44       neut        q       q
# 1481      blue      pink  long      5        54       neut        p       p
#
#       trialCorr?        RT tar,dis stim_loc  ITI  \
# 3            NaN       NaN      ('1', '12')  3.7
# 33           NaN       NaN      ('12', '9')  4.3
# 73           0.0  1.415677       ('1', '6')  3.7
# 128          1.0  1.232174      ('9', '12')  4.5
# 133          1.0  1.498918       ('3', '9')  4.4
# 158          1.0  1.298898      ('11', '9')  3.5
# 188          NaN       NaN      ('11', '5')  3.6
# 218          1.0  1.165597       ('3', '1')  3.4
# 228          1.0  1.065592       ('7', '6')  3.8
# 298          NaN       NaN      ('12', '6')  3.8
# 325          NaN       NaN      ('7', '12')  4.2
# 355          NaN       NaN       ('7', '3')  4.5
# 390          NaN       NaN      ('3', '12')  3.9
# 440          NaN       NaN       ('3', '9')  3.5
# 450          NaN       NaN       ('6', '3')  3.4
# 480          1.0  1.115665       ('3', '1')  4.6
# 515          NaN       NaN       ('6', '3')  4.2
# 550          1.0  1.582182       ('1', '5')  4.2
# 585          1.0  1.332271      ('12', '9')  3.8
# 595          NaN       NaN      ('12', '1')  3.5
# 647          1.0  1.115673      ('11', '9')  4.1
# 652          1.0  1.016449       ('6', '3')  3.7
# 677          1.0  1.332319      ('7', '11')  3.5
# 727          1.0  1.099003      ('6', '11')  4.3
# 747          1.0  0.965677       ('9', '6')  3.8
# 752          NaN       NaN      ('12', '1')  4.0
# 762          1.0  0.748955      ('1', '12')  3.8
# 867          1.0  0.982298       ('3', '6')  4.0
# 882          1.0  1.198888       ('1', '9')  4.6
# 887          1.0  1.232280       ('7', '6')  3.4
# 919          1.0  1.283135       ('6', '1')  4.5
# 924          1.0  1.215653      ('5', '12')  4.2
# 944          NaN       NaN       ('1', '3')  4.1
# 954          1.0  1.215665       ('9', '5')  4.1
# 964          1.0  1.198919       ('1', '3')  4.1
# 994          1.0  1.148847      ('11', '9')  3.5
# 1014         1.0  1.265659       ('1', '7')  4.3
# 1064         1.0  1.182277       ('1', '5')  4.0
# 1094         1.0  1.098937      ('3', '12')  4.0
# 1174         1.0  1.248924      ('12', '5')  4.2
# 1211         1.0  1.148790       ('6', '1')  3.7
# 1216         1.0  1.465656       ('5', '1')  4.0
# 1281         1.0  0.898956      ('1', '12')  3.9
# 1316         1.0  1.382252       ('3', '9')  4.0
# 1351         NaN       NaN      ('11', '3')  4.4
# 1366         NaN       NaN     ('11', '12')  3.9
# 1391         1.0  0.932270       ('9', '5')  4.1
# 1406         1.0  1.548994       ('7', '9')  3.8
# 1431         1.0  1.448907      ('12', '7')  4.4
# 1481         1.0  0.848934       ('5', '3')  3.8
#
#                                           Tar,Dis,Other      trial_trigs  \
# 3     ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 33    ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 73    ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 128   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 133   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 158   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 188   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 218   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 228   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 298   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 325   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 355   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 390   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 440   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 450   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 480   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 515   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 550   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 585   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 595   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 647   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 652   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 677   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 727   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 747   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 752   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 762   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 867   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 882   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 887   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 919   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 924   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 944   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 954   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 964   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 994   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1014  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1064  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1094  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1174  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1211  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1216  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1281  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1316  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1351  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1366  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1391  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 1406  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1431  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 1481  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
#
#                                                triggers
# 3     ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 33    ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 73    ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 128   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 133   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 158   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 188   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 218   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 228   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 298   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 325   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 355   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 390   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 440   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 450   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 480   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 515   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 550   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 585   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 595   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 647   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 652   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 677   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 727   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 747   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 752   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 762   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 867   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 882   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 887   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 919   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 924   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 944   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 954   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 964   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 994   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1014  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1064  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1094  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1174  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1211  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1216  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1281  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1316  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1351  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1366  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1391  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1406  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1431  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...
# 1481  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...

# %%
freqs=np.arange(.5,38.,2.)
n_cycles = freqs / 2.
leftPost_elecs=['CP5','CP3','P7','P5','P3','PO3','PO7']
rightPost_elecs=['CP4','CP6','P4','P6','P8','PO4','PO8']
all_conds=['tarShortCue_trig','disShortCue_trig',
           'tarLongCue_trig','disLongCue_trig']
all_subs_Lefts={}
all_subs_Rights={}
all_subs_Neutrals={}

for SubDict in [preprocCues_LeftH, preprocCues_RightH]:
    
    for cond in all_conds:
        
        if SubDict == preprocCues_LeftH:
            all_subs_Lefts[cond]={}
        else:
            all_subs_Rights[cond]={}
        for block_order in ['FirstFive','LastFive']:
            # loading an example subject to steal the python object's structure
            # and overwrite the subject data with a group average
            skeleton_obj=mne.time_frequency.tfr_morlet(SubDict['228'][cond][block_order],freqs=freqs,n_cycles=n_cycles,
                                                       average=True,use_fft=True,return_itc=False, decim=2, n_jobs=1)
            thisCond_blockOrder_allSubsDat=[]
            for s in list_subs:
                #print('\n\n\n')
                thisSub=SubDict[s][cond][block_order]
                print('extracting sub {0}, cond {1},block type {2}'.format(s,cond,block_order))
                subDat=mne.time_frequency.tfr_morlet(thisSub,freqs=freqs,n_cycles=n_cycles,average=True,
                                                         use_fft=True,return_itc=False, decim=2, n_jobs=1)
                thisCond_blockOrder_allSubsDat.append(subDat.data)

            # compiling all subjects' data for this condition, in this hemisphere
            all_subs_thisCond=np.stack(thisCond_blockOrder_allSubsDat)
            # and averaging across the "subject" dimension
            assert all_subs_thisCond.shape[0] == len(list_subs)
            all_subs_thisCond=all_subs_thisCond.mean(axis=0)
            # then feeding that into the skeleton MNE averageTFR object
            skeleton_obj.data=all_subs_thisCond

            skeleton_obj.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
            
            if SubDict==preprocCues_LeftH:
                #print(all_subs_Lefts[cond])
                all_subs_Lefts[cond][block_order]=skeleton_obj
                print('Finished with left hemis for this cond')
            elif SubDict==preprocCues_RightH:
                all_subs_Rights[cond][block_order]=skeleton_obj
                print('Finished with right hemis for this cond')
# Out:
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/scipy/fftpack/basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# extracting sub 224, cond tarShortCue_trig,block type FirstFive
# extracting sub 214, cond tarShortCue_trig,block type FirstFive
# extracting sub 211, cond tarShortCue_trig,block type FirstFive
# extracting sub 244, cond tarShortCue_trig,block type FirstFive
# extracting sub 225, cond tarShortCue_trig,block type FirstFive
# extracting sub 231, cond tarShortCue_trig,block type FirstFive
# extracting sub 241, cond tarShortCue_trig,block type FirstFive
# extracting sub 226, cond tarShortCue_trig,block type FirstFive
# extracting sub 233, cond tarShortCue_trig,block type FirstFive
# extracting sub 240, cond tarShortCue_trig,block type FirstFive
# extracting sub 223, cond tarShortCue_trig,block type FirstFive
# extracting sub 197, cond tarShortCue_trig,block type FirstFive
# extracting sub 228, cond tarShortCue_trig,block type FirstFive
# extracting sub 237, cond tarShortCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond tarShortCue_trig,block type LastFive
# extracting sub 214, cond tarShortCue_trig,block type LastFive
# extracting sub 211, cond tarShortCue_trig,block type LastFive
# extracting sub 244, cond tarShortCue_trig,block type LastFive
# extracting sub 225, cond tarShortCue_trig,block type LastFive
# extracting sub 231, cond tarShortCue_trig,block type LastFive
# extracting sub 241, cond tarShortCue_trig,block type LastFive
# extracting sub 226, cond tarShortCue_trig,block type LastFive
# extracting sub 233, cond tarShortCue_trig,block type LastFive
# extracting sub 240, cond tarShortCue_trig,block type LastFive
# extracting sub 223, cond tarShortCue_trig,block type LastFive
# extracting sub 197, cond tarShortCue_trig,block type LastFive
# extracting sub 228, cond tarShortCue_trig,block type LastFive
# extracting sub 237, cond tarShortCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond disShortCue_trig,block type FirstFive
# extracting sub 214, cond disShortCue_trig,block type FirstFive
# extracting sub 211, cond disShortCue_trig,block type FirstFive
# extracting sub 244, cond disShortCue_trig,block type FirstFive
# extracting sub 225, cond disShortCue_trig,block type FirstFive
# extracting sub 231, cond disShortCue_trig,block type FirstFive
# extracting sub 241, cond disShortCue_trig,block type FirstFive
# extracting sub 226, cond disShortCue_trig,block type FirstFive
# extracting sub 233, cond disShortCue_trig,block type FirstFive
# extracting sub 240, cond disShortCue_trig,block type FirstFive
# extracting sub 223, cond disShortCue_trig,block type FirstFive
# extracting sub 197, cond disShortCue_trig,block type FirstFive
# extracting sub 228, cond disShortCue_trig,block type FirstFive
# extracting sub 237, cond disShortCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond disShortCue_trig,block type LastFive
# extracting sub 214, cond disShortCue_trig,block type LastFive
# extracting sub 211, cond disShortCue_trig,block type LastFive
# extracting sub 244, cond disShortCue_trig,block type LastFive
# extracting sub 225, cond disShortCue_trig,block type LastFive
# extracting sub 231, cond disShortCue_trig,block type LastFive
# extracting sub 241, cond disShortCue_trig,block type LastFive
# extracting sub 226, cond disShortCue_trig,block type LastFive
# extracting sub 233, cond disShortCue_trig,block type LastFive
# extracting sub 240, cond disShortCue_trig,block type LastFive
# extracting sub 223, cond disShortCue_trig,block type LastFive
# extracting sub 197, cond disShortCue_trig,block type LastFive
# extracting sub 228, cond disShortCue_trig,block type LastFive
# extracting sub 237, cond disShortCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond tarLongCue_trig,block type FirstFive
# extracting sub 214, cond tarLongCue_trig,block type FirstFive
# extracting sub 211, cond tarLongCue_trig,block type FirstFive
# extracting sub 244, cond tarLongCue_trig,block type FirstFive
# extracting sub 225, cond tarLongCue_trig,block type FirstFive
# extracting sub 231, cond tarLongCue_trig,block type FirstFive
# extracting sub 241, cond tarLongCue_trig,block type FirstFive
# extracting sub 226, cond tarLongCue_trig,block type FirstFive
# extracting sub 233, cond tarLongCue_trig,block type FirstFive
# extracting sub 240, cond tarLongCue_trig,block type FirstFive
# extracting sub 223, cond tarLongCue_trig,block type FirstFive
# extracting sub 197, cond tarLongCue_trig,block type FirstFive
# extracting sub 228, cond tarLongCue_trig,block type FirstFive
# extracting sub 237, cond tarLongCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond tarLongCue_trig,block type LastFive
# extracting sub 214, cond tarLongCue_trig,block type LastFive
# extracting sub 211, cond tarLongCue_trig,block type LastFive
# extracting sub 244, cond tarLongCue_trig,block type LastFive
# extracting sub 225, cond tarLongCue_trig,block type LastFive
# extracting sub 231, cond tarLongCue_trig,block type LastFive
# extracting sub 241, cond tarLongCue_trig,block type LastFive
# extracting sub 226, cond tarLongCue_trig,block type LastFive
# extracting sub 233, cond tarLongCue_trig,block type LastFive
# extracting sub 240, cond tarLongCue_trig,block type LastFive
# extracting sub 223, cond tarLongCue_trig,block type LastFive
# extracting sub 197, cond tarLongCue_trig,block type LastFive
# extracting sub 228, cond tarLongCue_trig,block type LastFive
# extracting sub 237, cond tarLongCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond disLongCue_trig,block type FirstFive
# extracting sub 214, cond disLongCue_trig,block type FirstFive
# extracting sub 211, cond disLongCue_trig,block type FirstFive
# extracting sub 244, cond disLongCue_trig,block type FirstFive
# extracting sub 225, cond disLongCue_trig,block type FirstFive
# extracting sub 231, cond disLongCue_trig,block type FirstFive
# extracting sub 241, cond disLongCue_trig,block type FirstFive
# extracting sub 226, cond disLongCue_trig,block type FirstFive
# extracting sub 233, cond disLongCue_trig,block type FirstFive
# extracting sub 240, cond disLongCue_trig,block type FirstFive
# extracting sub 223, cond disLongCue_trig,block type FirstFive
# extracting sub 197, cond disLongCue_trig,block type FirstFive
# extracting sub 228, cond disLongCue_trig,block type FirstFive
# extracting sub 237, cond disLongCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond disLongCue_trig,block type LastFive
# extracting sub 214, cond disLongCue_trig,block type LastFive
# extracting sub 211, cond disLongCue_trig,block type LastFive
# extracting sub 244, cond disLongCue_trig,block type LastFive
# extracting sub 225, cond disLongCue_trig,block type LastFive
# extracting sub 231, cond disLongCue_trig,block type LastFive
# extracting sub 241, cond disLongCue_trig,block type LastFive
# extracting sub 226, cond disLongCue_trig,block type LastFive
# extracting sub 233, cond disLongCue_trig,block type LastFive
# extracting sub 240, cond disLongCue_trig,block type LastFive
# extracting sub 223, cond disLongCue_trig,block type LastFive
# extracting sub 197, cond disLongCue_trig,block type LastFive
# extracting sub 228, cond disLongCue_trig,block type LastFive
# extracting sub 237, cond disLongCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with left hemis for this cond
# extracting sub 224, cond tarShortCue_trig,block type FirstFive
# extracting sub 214, cond tarShortCue_trig,block type FirstFive
# extracting sub 211, cond tarShortCue_trig,block type FirstFive
# extracting sub 244, cond tarShortCue_trig,block type FirstFive
# extracting sub 225, cond tarShortCue_trig,block type FirstFive
# extracting sub 231, cond tarShortCue_trig,block type FirstFive
# extracting sub 241, cond tarShortCue_trig,block type FirstFive
# extracting sub 226, cond tarShortCue_trig,block type FirstFive
# extracting sub 233, cond tarShortCue_trig,block type FirstFive
# extracting sub 240, cond tarShortCue_trig,block type FirstFive
# extracting sub 223, cond tarShortCue_trig,block type FirstFive
# extracting sub 197, cond tarShortCue_trig,block type FirstFive
# extracting sub 228, cond tarShortCue_trig,block type FirstFive
# extracting sub 237, cond tarShortCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond tarShortCue_trig,block type LastFive
# extracting sub 214, cond tarShortCue_trig,block type LastFive
# extracting sub 211, cond tarShortCue_trig,block type LastFive
# extracting sub 244, cond tarShortCue_trig,block type LastFive
# extracting sub 225, cond tarShortCue_trig,block type LastFive
# extracting sub 231, cond tarShortCue_trig,block type LastFive
# extracting sub 241, cond tarShortCue_trig,block type LastFive
# extracting sub 226, cond tarShortCue_trig,block type LastFive
# extracting sub 233, cond tarShortCue_trig,block type LastFive
# extracting sub 240, cond tarShortCue_trig,block type LastFive
# extracting sub 223, cond tarShortCue_trig,block type LastFive
# extracting sub 197, cond tarShortCue_trig,block type LastFive
# extracting sub 228, cond tarShortCue_trig,block type LastFive
# extracting sub 237, cond tarShortCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond disShortCue_trig,block type FirstFive
# extracting sub 214, cond disShortCue_trig,block type FirstFive
# extracting sub 211, cond disShortCue_trig,block type FirstFive
# extracting sub 244, cond disShortCue_trig,block type FirstFive
# extracting sub 225, cond disShortCue_trig,block type FirstFive
# extracting sub 231, cond disShortCue_trig,block type FirstFive
# extracting sub 241, cond disShortCue_trig,block type FirstFive
# extracting sub 226, cond disShortCue_trig,block type FirstFive
# extracting sub 233, cond disShortCue_trig,block type FirstFive
# extracting sub 240, cond disShortCue_trig,block type FirstFive
# extracting sub 223, cond disShortCue_trig,block type FirstFive
# extracting sub 197, cond disShortCue_trig,block type FirstFive
# extracting sub 228, cond disShortCue_trig,block type FirstFive
# extracting sub 237, cond disShortCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond disShortCue_trig,block type LastFive
# extracting sub 214, cond disShortCue_trig,block type LastFive
# extracting sub 211, cond disShortCue_trig,block type LastFive
# extracting sub 244, cond disShortCue_trig,block type LastFive
# extracting sub 225, cond disShortCue_trig,block type LastFive
# extracting sub 231, cond disShortCue_trig,block type LastFive
# extracting sub 241, cond disShortCue_trig,block type LastFive
# extracting sub 226, cond disShortCue_trig,block type LastFive
# extracting sub 233, cond disShortCue_trig,block type LastFive
# extracting sub 240, cond disShortCue_trig,block type LastFive
# extracting sub 223, cond disShortCue_trig,block type LastFive
# extracting sub 197, cond disShortCue_trig,block type LastFive
# extracting sub 228, cond disShortCue_trig,block type LastFive
# extracting sub 237, cond disShortCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond tarLongCue_trig,block type FirstFive
# extracting sub 214, cond tarLongCue_trig,block type FirstFive
# extracting sub 211, cond tarLongCue_trig,block type FirstFive
# extracting sub 244, cond tarLongCue_trig,block type FirstFive
# extracting sub 225, cond tarLongCue_trig,block type FirstFive
# extracting sub 231, cond tarLongCue_trig,block type FirstFive
# extracting sub 241, cond tarLongCue_trig,block type FirstFive
# extracting sub 226, cond tarLongCue_trig,block type FirstFive
# extracting sub 233, cond tarLongCue_trig,block type FirstFive
# extracting sub 240, cond tarLongCue_trig,block type FirstFive
# extracting sub 223, cond tarLongCue_trig,block type FirstFive
# extracting sub 197, cond tarLongCue_trig,block type FirstFive
# extracting sub 228, cond tarLongCue_trig,block type FirstFive
# extracting sub 237, cond tarLongCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond tarLongCue_trig,block type LastFive
# extracting sub 214, cond tarLongCue_trig,block type LastFive
# extracting sub 211, cond tarLongCue_trig,block type LastFive
# extracting sub 244, cond tarLongCue_trig,block type LastFive
# extracting sub 225, cond tarLongCue_trig,block type LastFive
# extracting sub 231, cond tarLongCue_trig,block type LastFive
# extracting sub 241, cond tarLongCue_trig,block type LastFive
# extracting sub 226, cond tarLongCue_trig,block type LastFive
# extracting sub 233, cond tarLongCue_trig,block type LastFive
# extracting sub 240, cond tarLongCue_trig,block type LastFive
# extracting sub 223, cond tarLongCue_trig,block type LastFive
# extracting sub 197, cond tarLongCue_trig,block type LastFive
# extracting sub 228, cond tarLongCue_trig,block type LastFive
# extracting sub 237, cond tarLongCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond disLongCue_trig,block type FirstFive
# extracting sub 214, cond disLongCue_trig,block type FirstFive
# extracting sub 211, cond disLongCue_trig,block type FirstFive
# extracting sub 244, cond disLongCue_trig,block type FirstFive
# extracting sub 225, cond disLongCue_trig,block type FirstFive
# extracting sub 231, cond disLongCue_trig,block type FirstFive
# extracting sub 241, cond disLongCue_trig,block type FirstFive
# extracting sub 226, cond disLongCue_trig,block type FirstFive
# extracting sub 233, cond disLongCue_trig,block type FirstFive
# extracting sub 240, cond disLongCue_trig,block type FirstFive
# extracting sub 223, cond disLongCue_trig,block type FirstFive
# extracting sub 197, cond disLongCue_trig,block type FirstFive
# extracting sub 228, cond disLongCue_trig,block type FirstFive
# extracting sub 237, cond disLongCue_trig,block type FirstFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond
# extracting sub 224, cond disLongCue_trig,block type LastFive
# extracting sub 214, cond disLongCue_trig,block type LastFive
# extracting sub 211, cond disLongCue_trig,block type LastFive
# extracting sub 244, cond disLongCue_trig,block type LastFive
# extracting sub 225, cond disLongCue_trig,block type LastFive
# extracting sub 231, cond disLongCue_trig,block type LastFive
# extracting sub 241, cond disLongCue_trig,block type LastFive
# extracting sub 226, cond disLongCue_trig,block type LastFive
# extracting sub 233, cond disLongCue_trig,block type LastFive
# extracting sub 240, cond disLongCue_trig,block type LastFive
# extracting sub 223, cond disLongCue_trig,block type LastFive
# extracting sub 197, cond disLongCue_trig,block type LastFive
# extracting sub 228, cond disLongCue_trig,block type LastFive
# extracting sub 237, cond disLongCue_trig,block type LastFive
# Applying baseline correction (mode: zscore)
# Finished with right hemis for this cond

# %%
all_subs_thisCond.shape
# Out:
# (64, 19, 590)

# %%
#subDat_firsts.data
#all_subs_thisCond_firsts
#skeleton_obj_lastBlocks=mne.time_frequency.tfr_morlet(skeleton_neut_lastBlocks,freqs=freqs,n_cycles=n_cycles,
                                              #   average=True,use_fft=True,return_itc=False, decim=2, n_jobs=1)

print(all_subs_Lefts[cond])
#thisCond_allSubsDat_lasts
# Out:
# {'FirstFive': <AverageTFR  |  time : [-1.300781, 1.000000], freq : [0.500000, 36.500000], nave : 18, channels : 64, ~5.7 MB>, 'LastFive': <AverageTFR  |  time : [-1.300781, 1.000000], freq : [0.500000, 36.500000], nave : 12, channels : 64, ~5.7 MB>}

# %%
neuts=['neutLongCue_trig','neutShortCue_trig']
for SubDict in [preproc_cue_eps]:
    
    for cond in neuts: 
        # loading an example subject to steal the python object's structure
        # and overwrite the subject data with a group average
        skeleton_neut=SubDict['228'][cond]
        skeleton_neut_firstBlocks=skeleton_neut[skeleton_neut.metadata['block'] < 6]
        skeleton_neut_lastBlocks=skeleton_neut[skeleton_neut.metadata['block'] >= 6]

        skeleton_obj_firstBlocks=mne.time_frequency.tfr_morlet(skeleton_neut_firstBlocks,freqs=freqs,n_cycles=n_cycles,
                                                   average=True,use_fft=True,return_itc=False, decim=2, n_jobs=1)
        skeleton_obj_lastBlocks=mne.time_frequency.tfr_morlet(skeleton_neut_lastBlocks,freqs=freqs,n_cycles=n_cycles,
                                                   average=True,use_fft=True,return_itc=False, decim=2, n_jobs=1)
        
        thisCond_allSubsDat_firsts=[]
        thisCond_allSubsDat_lasts=[]
        for s in list_subs:
            #print('\n\n\n')
            thisSub=SubDict[s][cond]
            thisSub_firsts=thisSub[thisSub.metadata['block']<6]
            thisSub_lasts=thisSub[thisSub.metadata['block']>=6]
            print('extracting sub {0}, cond {1}'.format(s,cond))
            subDat_firsts=mne.time_frequency.tfr_morlet(thisSub_firsts,freqs=freqs,n_cycles=n_cycles,average=True,
                                                     use_fft=True,return_itc=False, decim=2, n_jobs=1)
            subDat_lasts=mne.time_frequency.tfr_morlet(thisSub_lasts,freqs=freqs,n_cycles=n_cycles,average=True,
                                                     use_fft=True,return_itc=False, decim=2, n_jobs=1)
            thisCond_allSubsDat_firsts.append(subDat_firsts.data)
            thisCond_allSubsDat_lasts.append(subDat_lasts.data)

        # compiling all subjects' data for this condition, in this hemisphere
        all_subs_thisCond_firsts=np.stack(thisCond_allSubsDat_firsts)
        # and averaging across the "subject" dimension
        assert all_subs_thisCond_firsts.shape[0] == len(list_subs)
        all_subs_thisCond_firsts=all_subs_thisCond_firsts.mean(axis=0)
        # then feeding that into the skeleton MNE averageTFR object
        skeleton_obj_firstBlocks.data=all_subs_thisCond_firsts

        skeleton_obj_firstBlocks.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))
        
        # compiling all subjects' data for this condition, in this hemisphere
        all_subs_thisCond_lasts=np.stack(thisCond_allSubsDat_lasts)
        # and averaging across the "subject" dimension
        assert all_subs_thisCond_lasts.shape[0] == len(list_subs)
        all_subs_thisCond_lasts=all_subs_thisCond_lasts.mean(axis=0)
        # then feeding that into the skeleton MNE averageTFR object
        skeleton_obj_lastBlocks.data=all_subs_thisCond_lasts

        skeleton_obj_lastBlocks.apply_baseline(mode='zscore', baseline=(-1.300, -0.5))


        all_subs_Neutrals[cond]={}
        all_subs_Neutrals[cond]['FirstFive']=skeleton_obj_firstBlocks
        all_subs_Neutrals[cond]['LastFive']=skeleton_obj_lastBlocks
        print('Finished with all subs epochs for this cond')
# Out:
# extracting sub 224, cond neutLongCue_trig
# extracting sub 214, cond neutLongCue_trig
# extracting sub 211, cond neutLongCue_trig
# extracting sub 244, cond neutLongCue_trig
# extracting sub 225, cond neutLongCue_trig
# extracting sub 231, cond neutLongCue_trig
# extracting sub 241, cond neutLongCue_trig
# extracting sub 226, cond neutLongCue_trig
# extracting sub 233, cond neutLongCue_trig
# extracting sub 240, cond neutLongCue_trig
# extracting sub 223, cond neutLongCue_trig
# extracting sub 197, cond neutLongCue_trig
# extracting sub 228, cond neutLongCue_trig
# extracting sub 237, cond neutLongCue_trig
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Finished with all subs epochs for this cond
# extracting sub 224, cond neutShortCue_trig
# extracting sub 214, cond neutShortCue_trig
# extracting sub 211, cond neutShortCue_trig
# extracting sub 244, cond neutShortCue_trig
# extracting sub 225, cond neutShortCue_trig
# extracting sub 231, cond neutShortCue_trig
# extracting sub 241, cond neutShortCue_trig
# extracting sub 226, cond neutShortCue_trig
# extracting sub 233, cond neutShortCue_trig
# extracting sub 240, cond neutShortCue_trig
# extracting sub 223, cond neutShortCue_trig
# extracting sub 197, cond neutShortCue_trig
# extracting sub 228, cond neutShortCue_trig
# extracting sub 237, cond neutShortCue_trig
# Applying baseline correction (mode: zscore)
# Applying baseline correction (mode: zscore)
# Finished with all subs epochs for this cond

# %% [markdown]
# ## Target Long SOA, target cue in right visual field, LAST FIVE blocks minus FIRST FIVE

# %%
#center.data
#latMinusCenter.data.shape

# %%
cond='tarLongCue_trig'
## Contrasting with centrally presented:
LastFive=all_subs_Rights[cond]['LastFive']
FirstFive=all_subs_Rights[cond]['FirstFive']
LastMinusFirst=LastFive-FirstFive
print('\n\nplotting RIGHT hemisphere last minus first blocks for %s\n' %cond)
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=rightPost_elecs,title='RIGHT Posterior Chs:').show()
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=leftPost_elecs,title='LEFT Posterior Chs:').show()

print('Plotting theta 0-200msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0,tmax=0.2,vmin=-6,vmax=6)
print('Plotting theta 200-400msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0.2,tmax=0.4,vmin=-6,vmax=6)
print('Plotting theta 400-800msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0.4,tmax=0.8,vmin=-6,vmax=6)
print('Plotting theta 800-1000msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0.8,tmax=1,vmin=-6,vmax=6)

print('Plotting Alpha band')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)

LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2,size=6,title='800-1000Ms')

mne.viz.plot_tfr_topomap(tfr=LastMinusFirst)
# Out:
# plotting RIGHT hemisphere last minus first blocks for tarLongCue_trig
#
# No baseline correction applied
# No baseline correction applied
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Plotting theta 0-200msec
# No baseline correction applied
# Plotting theta 200-400msec
# No baseline correction applied
# Plotting theta 400-800msec
# No baseline correction applied
# Plotting theta 800-1000msec
# No baseline correction applied
# Plotting Alpha band
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %% [markdown]
# ## Target Cue Long SOA, target cue in Left visual field, LAST FIVE BLOCKS minus FIRST FIVE

# %%
cond='tarLongCue_trig'
## Contrasting with centrally presented:
LastFive=all_subs_Lefts[cond]['LastFive']
FirstFive=all_subs_Lefts[cond]['FirstFive']
LastMinusFirst=LastFive-FirstFive
print('\n\nplotting LEFT hemisphere last minus first blocks for %s\n' %cond)
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=rightPost_elecs,title='RIGHT Posterior Chs:').show()
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=leftPost_elecs,title='LEFT Posterior Chs:').show()

print('Plotting theta 0-200msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0,tmax=0.2,vmin=-6,vmax=6)
print('Plotting theta 200-400msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0.2,tmax=0.4,vmin=-6,vmax=6)
print('Plotting theta 400-800msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0.4,tmax=0.8,vmin=-6,vmax=6)
print('Plotting theta 800-1000msec')
LastMinusFirst.plot_topomap(fmin=4,fmax=8,tmin=0.8,tmax=1,vmin=-6,vmax=6)

print('Plotting Alpha band')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2,size=6,title='L400-800Ms')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2,size=6,title='L800-1000Ms')
# Out:
# plotting LEFT hemisphere last minus first blocks for tarLongCue_trig
#
# No baseline correction applied
# No baseline correction applied
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Plotting theta 0-200msec
# No baseline correction applied
# Plotting theta 200-400msec
# No baseline correction applied
# Plotting theta 400-800msec
# No baseline correction applied
# Plotting theta 800-1000msec
# No baseline correction applied
# Plotting Alpha band
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %% [markdown]
# ## Distractor Long SOA, where distractor is on the right, LAST FIVE BLOCKS

# %%
cond='disLongCue_trig'
## Contrasting with centrally presented:
LastFive=all_subs_Rights[cond]['LastFive']
FirstFive=all_subs_Rights[cond]['FirstFive']
LastMinusFirst=LastFive-FirstFive
print('\n\nplotting RIGHT hemisphere last minus first blocks for %s\n' %cond)
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=rightPost_elecs,title='RIGHT Posterior Chs:').show()
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=leftPost_elecs,title='LEFT Posterior Chs:').show()

print('Plotting Alpha band')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2)
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2,size=6,title='R800-1000Ms')
# Out:
# plotting RIGHT hemisphere last minus first blocks for disLongCue_trig
#
# No baseline correction applied
# No baseline correction applied
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Plotting Alpha band
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied
# No baseline correction applied

# %% [markdown]
# ## Dis Long SOA, distractor on Left, last 5 blocks minus first 5

# %%
cond='disLongCue_trig'
## Contrasting with centrally presented:
LastFive=all_subs_Lefts[cond]['LastFive']
FirstFive=all_subs_Lefts[cond]['FirstFive']
LastMinusFirst=LastFive-FirstFive
print('\n\nplotting LEFT hemisphere last minus first blocks for %s\n' %cond)
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=rightPost_elecs,title='RIGHT Posterior Chs:').show()
LastMinusFirst.plot(vmin=-7,vmax=7,tmin=0,tmax=1,picks=leftPost_elecs,title='LEFT Posterior Chs:').show()

print('Plotting Alpha band')
print("0-200 MS")
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0,tmax=0.2,vmin=-2,vmax=2)
print('200-400 MS')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.2,tmax=0.4,vmin=-2,vmax=2)
print('400-800 MS')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.4,tmax=0.8,vmin=-2,vmax=2,size=6,title='L400-800Ms')
print('800-1000 MS')
LastMinusFirst.plot_topomap(fmin=8,fmax=14,tmin=0.8,tmax=1,vmin=-2,vmax=2,size=6,title='L800-1000Ms')
# Out:
# plotting LEFT hemisphere last minus first blocks for disLongCue_trig
#
# No baseline correction applied
# No baseline correction applied
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Plotting Alpha band
# 0-200 MS
# No baseline correction applied
# 200-400 MS
# No baseline correction applied
# 400-800 MS
# No baseline correction applied
# 800-1000 MS
# No baseline correction applied
