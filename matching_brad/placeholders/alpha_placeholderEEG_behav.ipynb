# %%
import seaborn as sns
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
where_files = r'/home/dcellier/RDSS/AlphaStudy_Data/eegData/eeg_behavior_data/'
files=os.listdir(where_files)
listDirectory=[f[:3] for f in files if 'matchingBrad' in f ]

# %%
np.unique(listDirectory)
# Out:
# array(['193', '196', '197', '198', '204', '206', '211', '212', '213',
#        '214', '222', '223', '224', '225', '226', '228', '230', '231',
#        '233', '234', '235', '237', '238', '239', '240', '241', '244',
#        '245', '247', '__D', '__O', 'tes'], dtype='<U3')

# %%
subs_list=['197','206','211','214','223',
             '224','225','226','228','233',
             '234','235','237','238','239', 
             '240','241','244','245','247',
             '231']

# %%
allSubs=pd.DataFrame()
allDfsList=[]
for sub in subs_list:
    thisSubDf=pd.DataFrame() #compile all of the csv's for ea subject
    for file in os.listdir(where_files):
        if (sub in file) and ("TRUNCATED" not in file) and ('compiled' not in file) and ('test' not in file):
            print(file)
            thisSub_data=pd.read_csv(where_files+file) #import subject data if filename matches pattern
            thisSub_data['subject']=sub
            thisSubDf=thisSubDf.append(thisSub_data)
    allDfsList.append(thisSubDf)
    allSubs=allSubs.append(thisSubDf)
# Out:
# __ORIGINAL_VERSION__197_alpha_placeholders_matchingBrad_01_2019_Nov_12_1319.csv
# 206_alpha_placeholders_matchingBrad_01_1_2019_Nov_15_1436.csv
# 206_alpha_placeholders_matchingBrad_01_2_2019_Nov_15_1452.csv
# 206_alpha_placeholders_matchingBrad_01_3_2019_Nov_15_1458.csv
# 206_alpha_placeholders_matchingBrad_01_4_2019_Nov_15_1505.csv
# 206_alpha_placeholders_matchingBrad_01_5_2019_Nov_15_1511.csv
# 206_alpha_placeholders_matchingBrad_01_6_2019_Nov_15_1518.csv
# 206_alpha_placeholders_matchingBrad_01_7_2019_Nov_15_1524.csv
# 206_alpha_placeholders_matchingBrad_01_8_2019_Nov_15_1530.csv
# 206_alpha_placeholders_matchingBrad_01_9_2019_Nov_15_1536.csv
# 206_alpha_placeholders_matchingBrad_01_10_2019_Nov_15_1542.csv
# 214_alpha_placeholders_matchingBrad_01_10_2019_Dec_04_1206.csv
# 211_alpha_placeholders_matchingBrad_01_1_2019_Nov_20_1155.csv
# 211_alpha_placeholders_matchingBrad_01_2_2019_Nov_20_1208.csv
# 211_alpha_placeholders_matchingBrad_01_3_2019_Nov_20_1214.csv
# ...

# %%
allSubs
# Out:
#    tar_color dis_color    SOA  block  trialNum trial_type corrResp subResp  \
# 0        red      pink  short      0         0        tar        q    None
# 1        red      pink   long      0         1        tar        p       p
# 2        red      pink  short      0         2        tar        p    None
# 3        red      pink  short      0         3       neut        p       p
# 4        red      pink   long      0         4       neut        p       p
# 5        red      pink   long      0         5        dis        p       p
# 6        red      pink  short      0         6        tar        p       p
# 7        red      pink   long      0         7        dis        q       q
# 8        red      pink  short      0         8        dis        p    None
# 9        red      pink  short      0         9        dis        q       q
# 10       red      pink   long      0        10        dis        p       p
# ...

# %%
allSubs.groupby(['trial_type','SOA']).mean()
# Out:
#                      block   trialNum  trialCorr?        RT       ITI
# trial_type SOA
# dis        long   5.144231  29.358654    0.889648  1.103053  4.013606
#            short  5.144231  29.847596    0.894505  1.155893  4.001298
# neut       long   5.144231  28.951442    0.932439  1.079701  4.001683
#            short  5.144231  29.441346    0.940421  1.056129  3.993365
# tar        long   5.144231  29.350000    0.972500  0.764773  3.998654
#            short  5.144231  30.050962    0.955231  0.881255  3.989663

# %%
plt.figure(figsize=(8,6))
ax=sns.barplot(y='RT',x='trial_type',hue='SOA',data=allSubs,palette='PuRd')
plt.legend(title='SOA: Long or Short')
#plt.ylim=(0,2)
plt.xlabel("\nTrial Type",size=25)
plt.ylabel("RT",size=25)
# Out:
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'RT')
