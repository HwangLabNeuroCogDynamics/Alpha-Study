# %%
import seaborn as sns
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
where_files = r'/home/dcellier/RDSS/AlphaStudy_Data/eegData/eeg_behavior_data/'
files=os.listdir(where_files)
listDirectory=[f[:3] for f in files if 'matchingBrad' in f ]

# %%
np.unique(listDirectory)
# Out:
# array(['193', '196', '197', '198', '204', '206', '211', '212', '213',
#        '214', '222', '223', '224', '225', '226', '228', '230', '233',
#        '__D', '__O', 'tes'], dtype='<U3')

# %%
subs_list=['198', '204', '206', '211', '212', '213',
           '214','222', '223', '224', '225', '226', '228', '230', '233']

# %%
allSubs=pd.DataFrame()
allDfsList=[]
for sub in subs_list:
    thisSubDf=pd.DataFrame() #compile all of the csv's for ea subject
    for file in os.listdir(where_files):
        if (sub in file) and ("TRUNCATED" not in file):
            print(file)
            thisSub_data=pd.read_csv(where_files+file) #import subject data if filename matches pattern
            thisSub_data['subject']=sub
            thisSubDf=thisSubDf.append(thisSub_data)
    allDfsList.append(thisSubDf)
    allSubs=allSubs.append(thisSubDf)
# Out:
# 198_alpha_placeholders_matchingBrad_01_2_2019_Nov_13_1139.csv
# 198_alpha_placeholders_matchingBrad_01_3_2019_Nov_13_1147.csv
# 198_alpha_placeholders_matchingBrad_01_4_2019_Nov_13_1154.csv
# 198_alpha_placeholders_matchingBrad_01_5_2019_Nov_13_1200.csv
# 198_alpha_placeholders_matchingBrad_01_6_2019_Nov_13_1207.csv
# 204_alpha_placeholders_matchingBrad_01_1_2019_Nov_13_1333.csv
# 204_alpha_placeholders_matchingBrad_01_2_2019_Nov_13_1344.csv
# 204_alpha_placeholders_matchingBrad_01_3_2019_Nov_13_1350.csv
# 204_alpha_placeholders_matchingBrad_01_4_2019_Nov_13_1357.csv
# 204_alpha_placeholders_matchingBrad_01_5_2019_Nov_13_1404.csv
# 204_alpha_placeholders_matchingBrad_01_6_2019_Nov_13_1414.csv
# 204_alpha_placeholders_matchingBrad_01_7_2019_Nov_13_1421.csv
# 204_alpha_placeholders_matchingBrad_01_8_2019_Nov_13_1427.csv
# 204_alpha_placeholders_matchingBrad_01_9_2019_Nov_13_1436.csv
# 204_alpha_placeholders_matchingBrad_01_10_2019_Nov_13_1443.csv
# 206_alpha_placeholders_matchingBrad_01_1_2019_Nov_15_1436.csv
# 206_alpha_placeholders_matchingBrad_01_2_2019_Nov_15_1452.csv
# 206_alpha_placeholders_matchingBrad_01_3_2019_Nov_15_1458.csv
# 206_alpha_placeholders_matchingBrad_01_4_2019_Nov_15_1505.csv
# 206_alpha_placeholders_matchingBrad_01_5_2019_Nov_15_1511.csv
# 206_alpha_placeholders_matchingBrad_01_6_2019_Nov_15_1518.csv
# 206_alpha_placeholders_matchingBrad_01_7_2019_Nov_15_1524.csv
# 206_alpha_placeholders_matchingBrad_01_8_2019_Nov_15_1530.csv
# 206_alpha_placeholders_matchingBrad_01_9_2019_Nov_15_1536.csv
# 206_alpha_placeholders_matchingBrad_01_10_2019_Nov_15_1542.csv
# 214_alpha_placeholders_matchingBrad_01_8_2019_Dec_04_1154.csv
# 214_alpha_placeholders_matchingBrad_01_9_2019_Dec_04_1200.csv
# 214_alpha_placeholders_matchingBrad_01_10_2019_Dec_04_1206.csv
# 222_alpha_placeholders_matchingBrad_01_1_2019_Dec_13_1426.csv
# 222_alpha_placeholders_matchingBrad_01_2_2019_Dec_13_1436.csv
# 222_alpha_placeholders_matchingBrad_01_3_2019_Dec_13_1442.csv
# 222_alpha_placeholders_matchingBrad_01_4_2019_Dec_13_1449.csv
# 222_alpha_placeholders_matchingBrad_01_5_2019_Dec_13_1455.csv
# 222_alpha_placeholders_matchingBrad_01_6_2019_Dec_13_1501.csv
# 222_alpha_placeholders_matchingBrad_01_7_2019_Dec_13_1508.csv
# 222_alpha_placeholders_matchingBrad_01_8_2019_Dec_13_1514.csv
# 222_alpha_placeholders_matchingBrad_01_9_2019_Dec_13_1520.csv
# 222_alpha_placeholders_matchingBrad_01_10_2019_Dec_13_1527.csv
# 223_alpha_placeholders_matchingBrad_01_1_2020_Jan_08_0914.csv
# 223_alpha_placeholders_matchingBrad_01_2_2020_Jan_08_0923.csv
# 223_alpha_placeholders_matchingBrad_01_3_2020_Jan_08_0929.csv
# 223_alpha_placeholders_matchingBrad_01_4_2020_Jan_08_0936.csv
# 223_alpha_placeholders_matchingBrad_01_5_2020_Jan_08_0942.csv
# 223_alpha_placeholders_matchingBrad_01_6_2020_Jan_08_1006.csv
# 223_alpha_placeholders_matchingBrad_01_7_2020_Jan_08_1013.csv
# 223_alpha_placeholders_matchingBrad_01_8_2020_Jan_08_1020.csv
# 223_alpha_placeholders_matchingBrad_01_9_2020_Jan_08_1026.csv
# 223_alpha_placeholders_matchingBrad_01_10_2020_Jan_08_1033.csv
# 224_alpha_placeholders_matchingBrad_01_1_2020_Jan_08_1600.csv
# 224_alpha_placeholders_matchingBrad_01_2_2020_Jan_08_1613.csv
# 224_alpha_placeholders_matchingBrad_01_3_2020_Jan_08_1620.csv
# 224_alpha_placeholders_matchingBrad_01_6_2020_Jan_08_1640.csv
# 224_alpha_placeholders_matchingBrad_01_4_2020_Jan_08_1627.csv
# 224_alpha_placeholders_matchingBrad_01_5_2020_Jan_08_1634.csv
# 224_alpha_placeholders_matchingBrad_01_7_2020_Jan_08_1647.csv
# 224_alpha_placeholders_matchingBrad_01_9_2020_Jan_08_1700.csv
# 224_alpha_placeholders_matchingBrad_01_10_2020_Jan_08_1713.csv
# 224_alpha_placeholders_matchingBrad_01_8_2020_Jan_08_1653.csv
# 224_alpha_placeholders_matchingBrad_01_10_2020_Jan_08_1706.csv
# 225_alpha_placeholders_matchingBrad_01_1_2020_Jan_09_1354.csv
# 225_alpha_placeholders_matchingBrad_01_2_2020_Jan_09_1409.csv
# 225_alpha_placeholders_matchingBrad_01_3_2020_Jan_09_1416.csv
# 225_alpha_placeholders_matchingBrad_01_4_2020_Jan_09_1422.csv
# 225_alpha_placeholders_matchingBrad_01_5_2020_Jan_09_1429.csv
# %%
allSubs
# Out:
#    tar_color dis_color    SOA  block  trialNum trial_type corrResp subResp  \
# 0        red      blue   long      0         0        tar        p       p
# 1        red      blue   long      0         1       neut        q       q
# 2        red      blue   long      0         2       neut        q       q
# 3        red      blue   long      0         3       neut        q       q
# 4        red      blue   long      0         4        dis        p       q
# 5        red      blue  short      0         5        dis        q    None
# 6        red      blue   long      0         6        dis        q       q
# 7        red      blue  short      0         7        tar        p       p
# 8        red      blue   long      0         8        tar        p       p
# 9        red      blue   long      0         9        tar        q       q
# 10       red      blue  short      0        10        dis        q       q
# 11       red      blue  short      0        11       neut        p       p
# 12       red      blue  short      0        12        tar        p       q
# 13       red      blue   long      0        13       neut        p       p
# 14       red      blue   long      0        14        tar        p       q
# 15       red      blue  short      0        15        dis        p       p
# 16       red      blue   long      0        16        dis        p       p
# 17       red      blue  short      0        17        tar        q       q
# 18       red      blue   long      0        18        tar        p       p
# 19       red      blue  short      0        19        dis        p    None
# 20       red      blue  short      0        20        dis        q       q
# 21       red      blue  short      0        21        dis        p       p
# 22       red      blue  short      0        22        tar        q       q
# 23       red      blue   long      0        23       neut        q       q
# 24       red      blue  short      0        24        dis        p       p
# 25       red      blue   long      0        25        dis        p       p
# 26       red      blue   long      0        26        dis        p       p
# 27       red      blue  short      0        27       neut        q       q
# 28       red      blue  short      0        28       neut        p       p
# 29       red      blue  short      0        29        tar        p       p
# ..       ...       ...    ...    ...       ...        ...      ...     ...
# 30      blue       red   long      7        30       neut        q       p
# 31      blue       red  short      7        31        dis        p       p
# 32      blue       red   long      7        32        tar        p       p
# 33      blue       red   long      7        33        dis        q       q
# 34      blue       red   long      7        34        dis        p       p
# 35      blue       red   long      7        35        tar        p       p
# 36      blue       red  short      7        36        tar        q       q
# 37      blue       red  short      7        37        dis        q       q
# 38      blue       red  short      7        38       neut        p       p
# 39      blue       red   long      7        39        dis        p       p
# 40      blue       red   long      7        40       neut        p       p
# 41      blue       red  short      7        41        dis        p       p
# 42      blue       red  short      7        42        tar        q       q
# 43      blue       red   long      7        43       neut        q       q
# 44      blue       red   long      7        44       neut        q       q
# 45      blue       red   long      7        45        tar        p       p
# 46      blue       red  short      7        46        dis        q       q
# 47      blue       red   long      7        47        tar        p       p
# 48      blue       red   long      7        48        dis        q       q
# 49      blue       red  short      7        49       neut        p       p
# 50      blue       red   long      7        50        tar        p       p
# 51      blue       red  short      7        51       neut        q       q
# 52      blue       red  short      7        52        dis        q       p
# 53      blue       red   long      7        53        tar        p       p
# 54      blue       red  short      7        54        dis        p       p
# 55      blue       red  short      7        55        tar        q       q
# 56      blue       red   long      7        56       neut        q       q
# 57      blue       red   long      7        57        dis        p       p
# 58      blue       red  short      7        58        dis        p       p
# 59      blue       red   long      7        59       neut        q       q
#
#     trialCorr?        RT tar,dis stim_loc  ITI  \
# 0          1.0  0.982277      ('11', '1')  4.0
# 1          1.0  1.615633       ('9', '6')  3.7
# 2          1.0  1.282227       ('5', '6')  3.8
# 3          1.0  1.482240      ('12', '6')  4.6
# 4          0.0  0.833122       ('9', '5')  4.4
# 5          NaN       NaN       ('3', '9')  4.5
# 6          1.0  1.132316       ('9', '6')  3.7
# 7          1.0  1.348995       ('5', '9')  3.7
# 8          1.0  1.265612       ('5', '6')  3.7
# 9          1.0  1.115620       ('6', '5')  3.5
# 10         1.0  1.532237      ('11', '3')  4.3
# 11         1.0  1.065577      ('7', '11')  3.7
# 12         0.0  0.965638      ('11', '7')  4.6
# 13         1.0  1.282225      ('12', '7')  3.6
# 14         0.0  1.365614      ('9', '11')  3.4
# 15         1.0  1.082346       ('9', '1')  4.0
# 16         1.0  1.282253       ('7', '3')  4.3
# 17         1.0  1.015611      ('9', '11')  4.4
# 18         1.0  1.048958      ('11', '6')  3.4
# 19         NaN       NaN       ('7', '1')  3.6
# 20         1.0  1.232290       ('7', '5')  3.8
# 21         1.0  1.565692       ('9', '6')  4.4
# 22         1.0  0.815639       ('9', '7')  4.3
# 23         1.0  1.049013       ('7', '9')  3.5
# 24         1.0  1.232270      ('12', '5')  4.1
# 25         1.0  0.982281       ('9', '6')  3.9
# 26         1.0  1.232254      ('12', '5')  4.3
# 27         1.0  1.098984       ('3', '7')  4.5
# 28         1.0  1.182340       ('5', '1')  3.5
# 29         1.0  0.932309      ('6', '11')  4.0
# ..         ...       ...              ...  ...
# 30         0.0  1.064182      ('12', '7')  4.4
# 31         1.0  0.832464     ('12', '11')  3.5
# 32         1.0  0.530184      ('1', '11')  3.5
# 33         1.0  1.161231       ('3', '5')  3.6
# 34         1.0  0.730233       ('3', '5')  4.5
# 35         1.0  0.850370      ('11', '9')  4.6
# 36         1.0  0.581512       ('5', '9')  3.8
# 37         1.0  1.013070       ('3', '9')  4.2
# 38         1.0  0.897969       ('9', '5')  4.5
# 39         1.0  1.012166       ('7', '6')  3.9
# 40         1.0  0.963817       ('6', '1')  4.2
# 41         1.0  0.970633      ('3', '11')  4.1
# 42         1.0  1.115955      ('11', '7')  3.7
# 43         1.0  1.094123       ('6', '9')  3.6
# 44         1.0  0.733100      ('12', '1')  3.5
# 45         1.0  0.700474      ('5', '12')  4.3
# 46         1.0  1.184805      ('12', '9')  4.3
# 47         1.0  0.594130      ('11', '1')  3.4
# 48         1.0  0.860119      ('12', '5')  4.4
# 49         1.0  0.864809      ('3', '12')  3.9
# 50         1.0  0.530883      ('11', '7')  4.6
# 51         1.0  0.749156       ('3', '6')  3.6
# 52         0.0  1.049155       ('5', '6')  4.3
# 53         1.0  0.451428      ('9', '12')  4.5
# 54         1.0  0.898611       ('7', '5')  3.9
# 55         1.0  1.031087      ('3', '12')  4.2
# 56         1.0  0.680288       ('3', '5')  4.0
# 57         1.0  0.680457      ('3', '11')  4.0
# 58         1.0  0.915585       ('1', '6')  4.3
# 59         1.0  1.013026      ('1', '12')  3.6
#
#                                         Tar,Dis,Other      trial_trigs  \
# 0     ('red_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 1   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 2   ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
# 3   ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 4   ('green_circle', 'blue_diamond', 'green_diamond')  (103, 115, 131)
# 5   ('green_circle', 'blue_diamond', 'green_diamond')  (101, 113, 131)
# 6   ('green_circle', 'blue_diamond', 'green_diamond')  (103, 115, 131)
# 7     ('red_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 8     ('red_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 9     ('red_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 10  ('green_circle', 'blue_diamond', 'green_diamond')  (101, 113, 131)
# 11  ('green_circle', 'green_diamond', 'green_diamo...  (109, 121, 131)
# 12   ('red_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 13  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 14    ('red_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 15  ('green_circle', 'blue_diamond', 'green_diamond')  (101, 113, 131)
# 16  ('green_circle', 'blue_diamond', 'green_diamond')  (103, 115, 131)
# 17   ('red_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 18    ('red_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 19   ('green_diamond', 'blue_circle', 'green_circle')  (101, 113, 131)
# 20   ('green_diamond', 'blue_circle', 'green_circle')  (101, 113, 131)
# 21  ('green_circle', 'blue_diamond', 'green_diamond')  (101, 113, 131)
# 22   ('red_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# 23  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 24   ('green_diamond', 'blue_circle', 'green_circle')  (101, 113, 131)
# 25  ('green_circle', 'blue_diamond', 'green_diamond')  (103, 115, 131)
# 26  ('green_circle', 'blue_diamond', 'green_diamond')  (103, 115, 131)
# 27  ('green_diamond', 'green_circle', 'green_circle')  (109, 121, 131)
# 28  ('green_diamond', 'green_circle', 'green_circle')  (109, 121, 131)
# 29   ('red_circle', 'green_diamond', 'green_diamond')  (105, 117, 131)
# ..                                                ...              ...
# 30  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 31   ('green_circle', 'red_diamond', 'green_diamond')  (101, 113, 131)
# 32  ('blue_circle', 'green_diamond', 'green_diamond')  (107, 119, 131)
# 33   ('green_circle', 'red_diamond', 'green_diamond')  (103, 115, 131)
# 34   ('green_circle', 'red_diamond', 'green_diamond')  (103, 115, 131)
# 35   ('blue_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 36   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 37    ('green_diamond', 'red_circle', 'green_circle')  (101, 113, 131)
# 38  ('green_diamond', 'green_circle', 'green_circle')  (109, 121, 131)
# 39   ('green_circle', 'red_diamond', 'green_diamond')  (103, 115, 131)
# 40  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 41    ('green_diamond', 'red_circle', 'green_circle')  (101, 113, 131)
# 42   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 43  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 44  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 45  ('blue_circle', 'green_diamond', 'green_diamond')  (107, 119, 131)
# 46    ('green_diamond', 'red_circle', 'green_circle')  (101, 113, 131)
# 47   ('blue_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 48   ('green_circle', 'red_diamond', 'green_diamond')  (103, 115, 131)
# 49  ('green_circle', 'green_diamond', 'green_diamo...  (109, 121, 131)
# 50   ('blue_diamond', 'green_circle', 'green_circle')  (107, 119, 131)
# 51  ('green_diamond', 'green_circle', 'green_circle')  (109, 121, 131)
# 52    ('green_diamond', 'red_circle', 'green_circle')  (101, 113, 131)
# 53  ('blue_circle', 'green_diamond', 'green_diamond')  (107, 119, 131)
# 54    ('green_diamond', 'red_circle', 'green_circle')  (101, 113, 131)
# 55   ('blue_diamond', 'green_circle', 'green_circle')  (105, 117, 131)
# 56  ('green_diamond', 'green_circle', 'green_circle')  (111, 123, 131)
# 57    ('green_diamond', 'red_circle', 'green_circle')  (103, 115, 131)
# 58   ('green_circle', 'red_diamond', 'green_diamond')  (101, 113, 131)
# 59  ('green_circle', 'green_diamond', 'green_diamo...  (111, 123, 131)
#
#                                              triggers subject
# 0   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 1   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 2   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 3   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 4   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 5   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 6   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 7   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 8   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 9   ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 10  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 11  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 12  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 13  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 14  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 15  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 16  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 17  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 18  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 19  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 20  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 21  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 22  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 23  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 24  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 25  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 26  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 27  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 28  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# 29  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     198
# ..                                                ...     ...
# 30  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 31  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 32  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 33  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 34  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 35  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 36  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 37  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 38  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 39  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 40  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 41  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 42  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 43  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 44  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 45  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 46  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 47  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 48  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 49  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 50  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 51  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 52  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 53  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 54  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 55  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 56  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 57  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 58  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
# 59  ({'dis_short_cue_trig': 101, 'dis_long_cue_tri...     233
#
# [8400 rows x 16 columns]

# %%
allSubs.groupby(['trial_type','SOA']).mean()
# Out:
#                      block   trialNum  trialCorr?        RT       ITI
# trial_type SOA
# dis        long   3.757143  29.361429    0.887850  1.080573  4.006643
#            short  3.757143  30.287857    0.883702  1.139406  3.997857
# neut       long   3.757143  28.820000    0.926299  1.068974  3.992500
#            short  3.757143  30.197857    0.925039  1.034037  4.011857
# tar        long   3.757143  29.120000    0.975446  0.755009  4.005571
#            short  3.757143  29.212857    0.953243  0.905571  4.003786

# %%
plt.figure(figsize=(8,6))
ax=sns.barplot(y='RT',x='trial_type',hue='SOA',data=allSubs,palette='PuRd')
plt.legend(title='SOA: Long or Short')
#plt.ylim=(0,2)
plt.xlabel("\nTrial Type",size=25)
plt.ylabel("RT",size=25)
# Out:
# Text(0, 0.5, 'RT')
