# %%
import numpy as np  # whole numpy lib is available, prepend 'np.'
from numpy import average, std
from numpy.random import random, randint, normal, shuffle,uniform
import scipy
from scipy.stats import ttest_ind
import seaborn as sns
import fnmatch
import os  # handy system and path functions
import sys  # to get file system encoding
import csv
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd  
import matplotlib
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.1 (default, Dec 14 2018, 19:28:38)
# [GCC 7.3.0]
# Pandas version 0.23.4
# Matplotlib version 3.0.2

# %%
where_files = r'/home/dcellier/RDSS/AlphaStudy_Data/behavData/'
files=os.listdir(where_files)
all_subjects=[f[:3] for f in files if 'MATCHING' in f ]

# %%
all_subs_dfs=[] # a list of dataframes
all_subs_data=pd.DataFrame()
for sub_name in all_subjects:
    for f_name in files:
        pattern='%s_alpha_singleton_ColorConstant_MATCHING_BRAD_01_*_*_*_*.csv' %sub_name
        if fnmatch.fnmatch(f_name,pattern):
            print(f_name)
            thisSub_data=pd.read_csv(where_files+f_name) #import subject data if filename matches pattern
            thisSub_data['subject']=sub_name
            all_subs_dfs.append(thisSub_data)
            all_subs_data=all_subs_data.append(thisSub_data)
# Out:
# 194_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_07_1406.csv
# 195_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_08_1329.csv
# 205_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_13_1349.csv
# 207_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_18_0943.csv
# 208_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_18_1130.csv
# 209_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_19_1230.csv
# 210_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Nov_20_1131.csv
# 215_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_04_1329.csv
# 216_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_09_0935.csv
# 217_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_09_1106.csv
# 218_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_10_1250.csv
# 219_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_10_1356.csv
# 220_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_11_1404.csv
# 221_alpha_singleton_ColorConstant_MATCHING_BRAD_01_2019_Dec_11_1520.csv

# %%
all_subs_dfs[3]
# Out:
#      block  trialNum trial_type dis_PresentorAbsent corrResp subResp  \
# 0        0         0        dis             Present        q    None
# 1        0         1       neut              Absent        q       p
# 2        0         2        dis             Present        p    None
# 3        0         3       neut              Absent        p       q
# 4        0         4       neut             Present        q       q
# 5        0         5        dis             Present        q    None
# 6        0         6       neut             Present        q       q
# 7        0         7       neut             Present        q       p
# 8        0         8       neut              Absent        p       q
# 9        0         9       neut              Absent        q       q
# 10       0        10       neut             Present        q       p
# 11       0        11       neut              Absent        p       q
# 12       0        12       neut              Absent        p       p
# 13       0        13        dis             Present        q    None
# 14       0        14       neut              Absent        q       q
# 15       0        15        dis             Present        p       p
# 16       0        16       neut             Present        q    None
# 17       0        17       neut              Absent        p       q
# 18       0        18        dis             Present        p    None
# 19       0        19       neut              Absent        q       p
# 20       0        20        dis             Present        q       q
# 21       0        21       neut              Absent        q       q
# 22       0        22       neut              Absent        q    None
# 23       0        23       neut             Present        q       p
# 24       0        24       neut             Present        q       q
# 25       0        25       neut              Absent        q       q
# 26       0        26        dis             Present        p       q
# 27       0        27       neut              Absent        q    None
# 28       0        28       neut              Absent        p       q
# 29       0        29       neut              Absent        q       q
# ..     ...       ...        ...                 ...      ...     ...
# 482      7        34       neut              Absent        p       p
# 483      7        35        dis             Present        q       p
# 484      7        36       neut              Absent        q       q
# 485      7        37       neut              Absent        q    None
# 486      7        38       neut              Absent        q    None
# 487      7        39        dis             Present        q    None
# 488      7        40       neut              Absent        p    None
# 489      7        41       neut             Present        p    None
# 490      7        42       neut              Absent        q       p
# 491      7        43       neut              Absent        p       q
# 492      7        44       neut             Present        q       q
# 493      7        45        dis             Present        q       p
# 494      7        46       neut              Absent        q       q
# 495      7        47       neut              Absent        q    None
# 496      7        48        dis             Present        q       p
# 497      7        49       neut              Absent        q       q
# 498      7        50       neut              Absent        p    None
# 499      7        51       neut              Absent        q       q
# 500      7        52       neut             Present        p    None
# 501      7        53       neut             Present        p    None
# 502      7        54        dis             Present        p    None
# 503      7        55        dis             Present        q    None
# 504      7        56       neut              Absent        p    None
# 505      7        57       neut              Absent        p    None
# 506      7        58       neut             Present        p    None
# 507      7        59       neut              Absent        q    None
# 508      7        60       neut              Absent        q    None
# 509      7        61        dis             Present        q       q
# 510      7        62       neut              Absent        p    None
# 511      7        63       neut              Absent        p       p
#
#      trialCorr?        RT    stim_loc(T,D)  ITI  \
# 0           NaN       NaN       ('9', '1')  1.9
# 1           0.0  1.564995   ('7', 'noDis')  1.5
# 2           NaN       NaN      ('11', '7')  2.3
# 3           0.0  1.782327   ('7', 'noDis')  1.6
# 4           1.0  1.598268       ('3', '1')  2.2
# 5           NaN       NaN      ('12', '3')  2.0
# 6           1.0  1.431649      ('1', '12')  1.5
# 7           0.0  1.131758       ('5', '9')  2.2
# 8           0.0  1.681700   ('1', 'noDis')  1.7
# 9           1.0  1.798939   ('7', 'noDis')  2.3
# 10          0.0  1.314992      ('12', '1')  1.8
# 11          0.0  1.431742   ('1', 'noDis')  1.7
# 12          1.0  1.631643   ('1', 'noDis')  1.5
# 13          NaN       NaN       ('1', '7')  2.1
# 14          1.0  1.381745  ('12', 'noDis')  1.9
# 15          1.0  1.314995       ('1', '6')  1.6
# 16          NaN       NaN      ('11', '1')  2.5
# 17          0.0  1.099211   ('7', 'noDis')  2.1
# 18          NaN       NaN       ('6', '7')  1.4
# 19          0.0  1.698228   ('1', 'noDis')  1.7
# 20          1.0  1.549053      ('11', '9')  1.8
# 21          1.0  1.581642   ('1', 'noDis')  1.6
# 22          NaN       NaN  ('12', 'noDis')  1.4
# 23          0.0  1.265058      ('12', '9')  2.2
# 24          1.0  1.231712     ('12', '11')  1.8
# 25          1.0  1.215122   ('5', 'noDis')  2.6
# 26          0.0  1.581635       ('1', '7')  1.6
# 27          NaN       NaN   ('1', 'noDis')  2.1
# 28          0.0  1.914916   ('7', 'noDis')  1.8
# 29          1.0  1.598346   ('6', 'noDis')  2.1
# ..          ...       ...              ...  ...
# 482         1.0  0.732021   ('5', 'noDis')  2.6
# 483         0.0  1.131789      ('11', '3')  2.4
# 484         1.0  1.181802  ('12', 'noDis')  1.8
# 485         NaN       NaN   ('5', 'noDis')  2.0
# 486         NaN       NaN   ('5', 'noDis')  2.2
# 487         NaN       NaN       ('3', '1')  1.8
# 488         NaN       NaN   ('5', 'noDis')  2.0
# 489         NaN       NaN       ('6', '5')  2.4
# 490         0.0  1.098498   ('3', 'noDis')  1.9
# 491         0.0  0.781821   ('7', 'noDis')  2.4
# 492         1.0  1.265000      ('12', '1')  1.5
# 493         0.0  1.081816      ('3', '12')  2.6
# 494         1.0  1.399097   ('7', 'noDis')  1.7
# 495         NaN       NaN   ('5', 'noDis')  1.7
# 496         0.0  1.065160       ('5', '6')  2.6
# 497         1.0  1.465044  ('12', 'noDis')  2.6
# 498         NaN       NaN   ('9', 'noDis')  2.5
# 499         1.0  1.065174   ('9', 'noDis')  1.7
# 500         NaN       NaN      ('7', '12')  2.4
# 501         NaN       NaN       ('9', '6')  1.8
# 502         NaN       NaN       ('6', '9')  1.6
# 503         NaN       NaN       ('5', '3')  1.4
# 504         NaN       NaN   ('6', 'noDis')  1.8
# 505         NaN       NaN   ('1', 'noDis')  2.6
# 506         NaN       NaN      ('9', '11')  1.9
# 507         NaN       NaN  ('11', 'noDis')  1.8
# 508         NaN       NaN  ('11', 'noDis')  2.2
# 509         1.0  1.181764      ('7', '11')  1.6
# 510         NaN       NaN   ('9', 'noDis')  2.6
# 511         1.0  1.798260   ('7', 'noDis')  1.6
#
#                                         Tar,Dis,Other trial_trigs  triggers  \
# 0     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 1          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 2     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 3          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 4    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 5     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 6    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 7    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 8          ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 9          ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 10    ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 11         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 12         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 13   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 14         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 15    ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 16   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 17         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 18   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 19         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 20   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 21         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 22         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 23   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 24   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 25         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 26   ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 27         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 28         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 29         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# ..                                                ...         ...       ...
# 482        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 483   ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 484        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 485        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 486        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 487  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 488        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 489   ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 490        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 491        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 492   ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 493  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 494        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 495        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 496   ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 497        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 498        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 499        ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 500  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 501  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 502  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 503  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 504        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 505        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 506  ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 507        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 508        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 509   ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 510        ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 511        ('green_diamond', 'noDis', 'green_circle')        None       NaN
#
#     subject
# 0       207
# 1       207
# 2       207
# 3       207
# 4       207
# 5       207
# 6       207
# 7       207
# 8       207
# 9       207
# 10      207
# 11      207
# 12      207
# 13      207
# 14      207
# 15      207
# 16      207
# 17      207
# 18      207
# 19      207
# 20      207
# 21      207
# 22      207
# 23      207
# 24      207
# 25      207
# 26      207
# 27      207
# 28      207
# 29      207
# ..      ...
# 482     207
# 483     207
# 484     207
# 485     207
# 486     207
# 487     207
# 488     207
# 489     207
# 490     207
# 491     207
# 492     207
# 493     207
# 494     207
# 495     207
# 496     207
# 497     207
# 498     207
# 499     207
# 500     207
# 501     207
# 502     207
# 503     207
# 504     207
# 505     207
# 506     207
# 507     207
# 508     207
# 509     207
# 510     207
# 511     207
#
# [512 rows x 14 columns]

# %%
all_subs_data
# Out:
#      block  trialNum trial_type dis_PresentorAbsent corrResp subResp  \
# 0        0         0       neut              Absent        q       q
# 1        0         1       neut             Present        q       q
# 2        0         2       neut              Absent        p    None
# 3        0         3       neut             Present        p       p
# 4        0         4       neut             Present        q       q
# 5        0         5       neut              Absent        p       p
# 6        0         6       neut              Absent        q       q
# 7        0         7       neut              Absent        p       p
# 8        0         8        dis             Present        q       q
# 9        0         9       neut             Present        q       q
# 10       0        10        dis             Present        p       p
# 11       0        11       neut              Absent        q       q
# 12       0        12        dis             Present        q       q
# 13       0        13       neut             Present        q       q
# 14       0        14       neut              Absent        p       p
# 15       0        15        dis             Present        q       q
# 16       0        16       neut              Absent        p       p
# 17       0        17       neut              Absent        p       p
# 18       0        18       neut             Present        q       q
# 19       0        19       neut              Absent        p       p
# 20       0        20       neut             Present        q       q
# 21       0        21       neut              Absent        q       q
# 22       0        22       neut             Present        q       q
# 23       0        23        dis             Present        q       q
# 24       0        24       neut              Absent        p       p
# 25       0        25       neut             Present        p       p
# 26       0        26       neut              Absent        q       q
# 27       0        27        dis             Present        q       q
# 28       0        28       neut              Absent        p       p
# 29       0        29       neut              Absent        p       p
# ..     ...       ...        ...                 ...      ...     ...
# 482      7        34       neut             Present        p       p
# 483      7        35       neut             Present        p       p
# 484      7        36        dis             Present        q       q
# 485      7        37       neut              Absent        p       p
# 486      7        38       neut              Absent        p       p
# 487      7        39        dis             Present        q       q
# 488      7        40       neut             Present        q       q
# 489      7        41       neut             Present        p       p
# 490      7        42       neut             Present        p       p
# 491      7        43       neut              Absent        q       q
# 492      7        44       neut              Absent        q       q
# 493      7        45       neut             Present        q       q
# 494      7        46       neut              Absent        p       p
# 495      7        47        dis             Present        q       q
# 496      7        48       neut              Absent        q       p
# 497      7        49       neut             Present        p       p
# 498      7        50        dis             Present        q       q
# 499      7        51       neut              Absent        q       q
# 500      7        52       neut              Absent        p       p
# 501      7        53       neut              Absent        q       q
# 502      7        54       neut             Present        p       p
# 503      7        55       neut              Absent        p       p
# 504      7        56       neut             Present        p       p
# 505      7        57       neut              Absent        q       q
# 506      7        58        dis             Present        p       p
# 507      7        59        dis             Present        p       p
# 508      7        60       neut             Present        p       p
# 509      7        61        dis             Present        q       q
# 510      7        62        dis             Present        q       q
# 511      7        63       neut             Present        q       q
#
#      trialCorr?        RT    stim_loc(T,D)  ITI  \
# 0           1.0  1.648246   ('6', 'noDis')  2.3
# 1           1.0  0.998513       ('5', '6')  2.0
# 2           NaN       NaN   ('6', 'noDis')  1.9
# 3           1.0  1.398361       ('7', '5')  2.6
# 4           1.0  1.298404      ('3', '11')  2.2
# 5           1.0  1.598344   ('5', 'noDis')  2.5
# 6           1.0  1.315121   ('9', 'noDis')  2.1
# 7           1.0  1.831318   ('6', 'noDis')  1.9
# 8           1.0  1.448369       ('9', '1')  1.6
# 9           1.0  1.381675       ('6', '3')  1.9
# 10          1.0  1.398425      ('11', '1')  2.6
# 11          1.0  1.981556  ('12', 'noDis')  1.6
# 12          1.0  1.598317       ('6', '9')  1.9
# 13          1.0  1.515001      ('6', '11')  1.5
# 14          1.0  1.298450   ('3', 'noDis')  1.7
# 15          1.0  1.148467       ('3', '1')  2.4
# 16          1.0  1.581619   ('6', 'noDis')  2.4
# 17          1.0  1.098397   ('3', 'noDis')  1.5
# 18          1.0  1.648235       ('9', '3')  2.3
# 19          1.0  1.465051   ('3', 'noDis')  2.3
# 20          1.0  1.915596      ('5', '11')  1.6
# 21          1.0  0.798605  ('12', 'noDis')  1.6
# 22          1.0  1.598279      ('11', '6')  2.1
# 23          1.0  1.048487       ('9', '6')  1.4
# 24          1.0  1.231804  ('11', 'noDis')  1.4
# 25          1.0  1.181762       ('9', '3')  1.5
# 26          1.0  1.764955   ('7', 'noDis')  1.9
# 27          1.0  1.698254       ('6', '1')  2.0
# 28          1.0  1.531798   ('7', 'noDis')  1.5
# 29          1.0  1.315092   ('6', 'noDis')  2.5
# ..          ...       ...              ...  ...
# 482         1.0  1.164891       ('7', '9')  2.5
# 483         1.0  0.881769      ('11', '7')  2.0
# 484         1.0  1.115020      ('12', '3')  2.3
# 485         1.0  0.698472   ('5', 'noDis')  1.6
# 486         1.0  1.914610  ('12', 'noDis')  2.1
# 487         1.0  0.915039       ('3', '6')  1.4
# 488         1.0  0.848417       ('6', '3')  2.5
# 489         1.0  1.381543      ('11', '5')  1.6
# 490         1.0  0.864927      ('12', '6')  2.5
# 491         1.0  0.981708   ('7', 'noDis')  2.0
# 492         1.0  1.481508  ('11', 'noDis')  1.9
# 493         1.0  1.498110       ('6', '5')  1.4
# 494         1.0  1.948061  ('11', 'noDis')  1.8
# 495         1.0  0.831761       ('3', '9')  1.7
# 496         0.0  0.948276   ('5', 'noDis')  1.7
# 497         1.0  0.948239       ('5', '7')  2.2
# 498         1.0  0.981756      ('9', '12')  1.6
# 499         1.0  1.181508   ('3', 'noDis')  1.7
# 500         1.0  0.815014   ('6', 'noDis')  2.5
# 501         1.0  1.564803   ('5', 'noDis')  2.4
# 502         1.0  0.865850      ('11', '1')  2.2
# 503         1.0  0.665217  ('11', 'noDis')  2.4
# 504         1.0  0.948217      ('3', '12')  2.1
# 505         1.0  1.948065   ('1', 'noDis')  2.4
# 506         1.0  1.231482       ('1', '9')  2.5
# 507         1.0  1.514676       ('5', '1')  1.9
# 508         1.0  0.765046      ('11', '1')  2.1
# 509         1.0  1.698130       ('7', '6')  1.7
# 510         1.0  1.181477       ('6', '1')  2.0
# 511         1.0  1.064853      ('11', '9')  1.8
#
#                                          Tar,Dis,Other trial_trigs  triggers  \
# 0           ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 1     ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 2           ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 3     ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 4      ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 5           ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 6           ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 7           ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 8     ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 9     ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 10    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 11          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 12    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 13     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 14          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 15     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 16          ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 17          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 18     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 19          ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 20     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 21          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 22    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 23     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 24          ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 25     ('green_diamond', 'red_circle', 'green_circle')        None       NaN
# 26          ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 27    ('green_circle', 'red_diamond', 'green_diamond')        None       NaN
# 28          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 29          ('green_diamond', 'noDis', 'green_circle')        None       NaN
# ..                                                 ...         ...       ...
# 482   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 483  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 484   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 485         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 486         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 487   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 488   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 489  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 490  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 491         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 492         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 493  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 494         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 495   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 496         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 497  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 498   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 499         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 500         ('green_circle', 'noDis', 'green_diamond')        None       NaN
# 501         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 502   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 503         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 504  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 505         ('green_diamond', 'noDis', 'green_circle')        None       NaN
# 506  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 507  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 508  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 509   ('green_diamond', 'blue_circle', 'green_circle')        None       NaN
# 510  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
# 511  ('green_circle', 'blue_diamond', 'green_diamond')        None       NaN
#
#     subject
# 0       194
# 1       194
# 2       194
# 3       194
# 4       194
# 5       194
# 6       194
# 7       194
# 8       194
# 9       194
# 10      194
# 11      194
# 12      194
# 13      194
# 14      194
# 15      194
# 16      194
# 17      194
# 18      194
# 19      194
# 20      194
# 21      194
# 22      194
# 23      194
# 24      194
# 25      194
# 26      194
# 27      194
# 28      194
# 29      194
# ..      ...
# 482     221
# 483     221
# 484     221
# 485     221
# 486     221
# 487     221
# 488     221
# 489     221
# 490     221
# 491     221
# 492     221
# 493     221
# 494     221
# 495     221
# 496     221
# 497     221
# 498     221
# 499     221
# 500     221
# 501     221
# 502     221
# 503     221
# 504     221
# 505     221
# 506     221
# 507     221
# 508     221
# 509     221
# 510     221
# 511     221
#
# [7168 rows x 14 columns]

# %%
all_subs_data.groupby(['trial_type','dis_PresentorAbsent']).mean()
# Out:
#                                 block   trialNum  trialCorr?        RT  \
# trial_type dis_PresentorAbsent
# dis        Present                3.5  31.294643    0.920223  1.114244
# neut       Absent                 3.5  31.763114    0.942131  1.043604
#            Present                3.5  31.179129    0.924923  1.125098
#
#                                      ITI  triggers
# trial_type dis_PresentorAbsent
# dis        Present              2.017801       NaN
# neut       Absent               2.000781       NaN
#            Present              1.993248       NaN

# %%
plt.figure(figsize=(8,6))
ax=sns.barplot(y='RT',x='trial_type',hue='dis_PresentorAbsent',data=all_subs_data,palette='PuRd')
plt.legend(title='Distractor Present or Absent')
#plt.ylim=(0,2)
plt.xlabel("Trial Type",size=25)
plt.ylabel("RT",size=25)
# Out:
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0, 0.5, 'RT')
