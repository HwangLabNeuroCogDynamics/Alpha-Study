# %% [markdown]
# First, we have to import the functions and packages relevant to our script

# %%
import numpy as np  # whole numpy lib is available, prepend 'np.'
from numpy import average, std
from numpy.random import random, randint, normal, shuffle,uniform
import os  # handy system and path functions
import sys  # to get file system encoding
import csv
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd  
import matplotlib
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.3 |Anaconda, Inc.| (default, Oct 15 2017, 03:27:45) [MSC v.1900 64 bit (AMD64)]
# Pandas version 0.20.3
# Matplotlib version 2.1.0

# %% [markdown]
# Now we're going to want to pull up an example of one .csv results file and extract its data

# %%
cue_conditions=['target','distractor','neutral']
valid_conds=[0.5,0.8]
numTrials=33
subjects=['99']
sessions=3
#path to .csv result files with our mock data 
where_files = r'C:\Users\dillc\University of Iowa\Hwang Lab - Documents\Alpha Paradigm\scripts\data'

# %% [markdown]
# # First, we'll look at the results of one subject

# %%
results = pd.read_csv(where_files +r'\99_alpha_pilot_01_2018.csv') #https://www.tutorialspoint.com/python_pandas/python_pandas_dataframe.htm
#results.fillna('')
results.columns
# Out:
# Index(['flex or blocked?', 'no stim', 'TarInDistFlag', 'lateralized?', 'block',
#        'cue', 'validity', 'trialNum', 'trial_type', 'corrResp', 'subResp',
#        'trialCorr?', 'RT', 'tarinDisCond', 'ITI'],
#       dtype='object')

# %%
block_results=results.iloc[1:,4:]
block_results
block_results.fillna('')
# Out:
#     block     cue validity  trialNum trial_type corrResp subResp  trialCorr?  \
# 1       2  target      0.5       1.0    invalid       up      up         1.0
# 2                                2.0    invalid     down    down         1.0
# 3                                3.0      valid    right   right         1.0
# 4                                4.0      valid     down    down         1.0
# 5                                5.0      valid     left    left         1.0
# 6                                6.0    invalid       up      up         1.0
# 7                                7.0      valid       up      up         1.0
# 8                                8.0    invalid     left    left         1.0
# 9                                9.0    invalid     left    left         1.0
# 10                              10.0    invalid     down    down         1.0
# 11                              11.0      valid     left    left         1.0
# 12                              12.0      valid    right   right         1.0
# 13                              13.0      valid    right   right         1.0
# 14                              14.0      valid    right   right         1.0
# 15                              15.0      valid    right   right         1.0
# 16                              16.0    invalid       up      up         1.0
# 17                              17.0    invalid     down    down         1.0
# 18                              18.0      valid    right   right         1.0
# 19                              19.0    invalid       up      up         1.0
# 20                              20.0    invalid     left    left         1.0
# 21                              21.0    invalid     down    down         1.0
# 22                              22.0      valid     left    left         1.0
# 23                              23.0      valid     down      up         0.0
# 24                              24.0      valid     down    down         1.0
# 25                              25.0    invalid       up      up         1.0
# 26                              26.0    invalid     down    down         1.0
# 27                              27.0      valid    right    down         0.0
# 28                              28.0    invalid    right   right         1.0
# 29                              29.0    invalid     down    down         1.0
# 30                              30.0      valid     down    left         0.0
# ..    ...     ...      ...       ...        ...      ...     ...         ...
# 136                              4.0        n/a     down    down         1.0
# 137                              5.0        n/a     down   right         0.0
# 138                              6.0        n/a     left    left         1.0
# 139                              7.0        n/a    right   right         1.0
# 140                              8.0        n/a    right   right         1.0
# 141                              9.0        n/a    right   right         1.0
# 142                             10.0        n/a    right   right         1.0
# 143                             11.0        n/a       up      up         1.0
# 144                             12.0        n/a     down   right         0.0
# 145                             13.0        n/a     left   right         0.0
# 146                             14.0        n/a     left    left         1.0
# 147                             15.0        n/a     down    None         0.0
# 148                             16.0        n/a     left    left         1.0
# 160  0.7459237273578765           0.0  4.221409
# 161  1.1475401211209828           0.0  3.958741
# 162   0.657141729752766           0.0  4.388051
# 163   0.757256063647219           0.0  4.114752
# 164  0.6041631779371528           0.0  4.012834
# 165  0.6395319368166383           0.0  3.998773
#
# [165 rows x 11 columns]

# %%
#extracting overall accuracy
accALL=(np.sum(block_results['trialCorr?'])/165)
accALL
# Out:
# 0.8848484848484849

# %% [markdown]
# Have to convert the RT dtype to floats instead of strings

# %%
block_results['RT']=block_results['RT'].replace('None',0)
block_results['RT']=block_results.RT.astype(float)

# %%
#overall mean
RTall=np.mean(block_results['RT'])
RTall
# Out:
# 0.8438402787100516

# %% [markdown]
# # Now, we'll look at data within subjects as well as across them

# %% [markdown]
# We want to look at condition-by-condition data, because averages across conditions aren't super informative on their own

# %%
# want to grab the indices of each condtion row and what condition it is (cue type AND validity)

#stats=pd.DataFrame

Condstats={}
for sub in subjects:
    print('subject '+str(sub)+':')
    for session in range(sessions):
        print('##### session '+str(session+1)+' #####')
        
        results = pd.read_csv(where_files +r'\%s_alpha_pilot_0%d_2018.csv'% (sub,(session+1)))
        block_results=results.iloc[1:,4:]
        block_results['RT']=block_results['RT'].replace('None',0)
        block_results['RT']=block_results.RT.astype(float)
        
        conds_indices={}
        for cue in cue_conditions: #loop through the cue categories and find their indices
            inds=block_results['cue'][block_results['cue']==cue].index
            #print(cue)
            #print(inds)
            for valid in valid_conds: #once we find the cue indices we still need to know the validity for those cue blocks
                if cue=='neutral' and inds.any():
                    conds_indices['neutral']=inds #neutral cues always have validity of 0 
                else:    
                    for ind in inds:
                        if block_results['validity'][ind]==valid:
                            conds_indices.setdefault((cue+str(valid)),[]).append(ind)
        #print(conds_indices) 

        ### now we have a dictionary of each condtion's indices in the DataFrame, so we next want to extract the data for each ###

        for cond in conds_indices.keys():
            print(cond+':')
            RTs=[]
            for ind in conds_indices[cond]: #slicing the series 'RT' by the indices of ea condition to grab out the RT's for this cond
                slce=block_results['RT'][(ind-1):(ind+(numTrials-1))]
                RTs.append(slce)
            cond_RT=pd.concat(RTs)
            print('mean RT: '+str(np.mean(cond_RT)))
            print('standard dev of RT: '+str(np.std(cond_RT)))
            ACCs=[]
            for ind in conds_indices[cond]: #slicing the series 'RT' by the indices of ea condition to grab out the RT's for this cond
                slce=block_results['trialCorr?'][(ind-1):(ind+(numTrials-1))]
                ACCs.append(slce)
            cond_ACC=pd.concat(ACCs)
            print('acc: '+str(np.mean(cond_ACC)))
            print('\n')
            
            Condstats[cond+' session '+str(session+1)]=[(np.mean(cond_RT)),(np.std(cond_RT)),(np.mean(cond_ACC))]
    
  
    print(Condstats)       
    #print('\n')
# Out:
# subject 99:
# ##### session 1 #####
# target0.5:
# mean RT: 0.8119709620002664
# standard dev of RT: 0.2374912871959076
# acc: 0.8787878787878788
#
#
# target0.8:
# mean RT: 0.8431061725471712
# standard dev of RT: 0.20788688729234286
# acc: 0.9090909090909091
#
#
# distractor0.5:
# mean RT: 0.9298115108443502
# standard dev of RT: 0.2802179522400999
# acc: 1.0
#
#
# distractor0.8:
# mean RT: 0.8941386995725087
# standard dev of RT: 0.2948363007707853
# acc: 0.8181818181818182
#
#
# neutral:
# mean RT: 0.7401740485859618
# standard dev of RT: 0.22309704241857353
# acc: 0.8181818181818182
#
#
# ##### session 2 #####
# target0.5:
# mean RT: 0.7743502302941069
# standard dev of RT: 0.19008069455340842
# acc: 0.9696969696969697
#
#
# target0.8:
# mean RT: 0.7664571167538683
# standard dev of RT: 0.16481630648745232
# acc: 0.9393939393939394
#
#
# distractor0.5:
# mean RT: 0.8470242070898442
# standard dev of RT: 0.1713615115388313
# acc: 0.9393939393939394
#
#
# distractor0.8:
# mean RT: 0.8025405645087382
# standard dev of RT: 0.14403240266290224
# acc: 1.0
#
#
# neutral:
# mean RT: 0.8006877278923198
# standard dev of RT: 0.1715902278294843
# acc: 0.9393939393939394
#
#
# ##### session 3 #####
# target0.5:
# mean RT: 0.7328276749255676
# standard dev of RT: 0.1818784911081051
# acc: 0.98989898989899
#
#
# {'target0.5 session 1': [0.8119709620002664, 0.2374912871959076, 0.8787878787878788], 'target0.8 session 1': [0.8431061725471712, 0.20788688729234286, 0.9090909090909091], 'distractor0.5 session 1': [0.9298115108443502, 0.2802179522400999, 1.0], 'distractor0.8 session 1': [0.8941386995725087, 0.2948363007707853, 0.8181818181818182], 'neutral session 1': [0.7401740485859618, 0.22309704241857353, 0.8181818181818182], 'target0.5 session 2': [0.7743502302941069, 0.19008069455340842, 0.9696969696969697], 'target0.8 session 2': [0.7664571167538683, 0.16481630648745232, 0.9393939393939394], 'distractor0.5 session 2': [0.8470242070898442, 0.1713615115388313, 0.9393939393939394], 'distractor0.8 session 2': [0.8025405645087382, 0.14403240266290224, 1.0], 'neutral session 2': [0.8006877278923198, 0.1715902278294843, 0.9393939393939394], 'target0.5 session 3': [0.7328276749255676, 0.1818784911081051, 0.98989898989899]}

# %%
# Data for plotting

meanRTs_tar5=(0.8119,0.77435,0.73282)
meanRTs_tar8=(0.84310,0.766457,0.83333)#last num is fake
meanRTs_dis5=(0.929811,0.84702,0.86532)#last num is fake
meanRTs_dis8=(0.894138,0.8025405,0.8506)#last num is fake
meanRTs_neutral=(0.74017,0.8006,0.7899)#last num is fake

plt.figure(figsize=(20,40))
fig, ax = plt.subplots()

ax.set(xlabel='conditions', ylabel='RT',
title='across sessions')
index=np.arange(3)
bar_width=0.35
opacity=0.5

a=plt.bar(index, meanRTs_tar5, bar_width,
                 alpha=opacity,
                 color='b',
                 label='tar5')
b=plt.bar(index, meanRTs_tar8, bar_width,
                 alpha=opacity,
                 color='g',
                 label='tar8')
c=plt.bar(index, meanRTs_dis5, bar_width,
                 alpha=opacity,
                 color='c',
                 label='dis5')
d=plt.bar(index, meanRTs_dis8, bar_width,
                 alpha=opacity,
                 color='r',
                 label='dis8')
e=plt.bar(index, meanRTs_neutral, bar_width,
                 alpha=opacity,
                 color='y',
                 label='neutral')

#x=['s1t0.5','s1t0.8','s1d0.5','s1d0.8','s1n','s2t0.5','s2t0.8','s2d0.5','s2d0.8','s2n','s3t0.5','s3t0.8','s3d0.5','s3d0.8','s3n']
plt.xticks(index+bar_width,('s1','s2','s3'))
#y=[]
plt.legend()
#plt.bar(x,1)
plt.show()
