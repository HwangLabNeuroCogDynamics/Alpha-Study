# %%
import numpy as np  # whole numpy lib is available, prepend 'np.'
from numpy import average, std
from numpy.random import random, randint, normal, shuffle,uniform
import scipy
from scipy.stats import ttest_ind
import seaborn as sns
import fnmatch
import os  # handy system and path functions
import sys  # to get file system encoding
import csv
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd  
import matplotlib
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.1 (default, Dec 14 2018, 19:28:38)
# [GCC 7.3.0]
# Pandas version 0.23.4
# Matplotlib version 3.0.2

# %%
subjects9=['111','112','113','114','115','116','117','118','119','122','123','124','125','126'] #alpha singleton pilot with colors+shapes randomized every trial
all_subjects=[subjects9]

# %%
#path to .csv result files with our data 
where_files = r'/home/dcellier/RDSS/AlphaStudy_Data/behavData/'

# %%
files=os.listdir(where_files)

# %%
#files

# %%
all_subs_dfs=[] # a list of dataframes
all_subs_data=pd.DataFrame()
for sub_list in all_subjects:
    for sub_name in sub_list:
        for f_name in files:
            pattern='%s_alpha_singleton_pilot_01_*_*_*_*.csv' %sub_name
            if fnmatch.fnmatch(f_name,pattern):
                print(f_name)
                thisSub_data=pd.read_csv(where_files+f_name) #import subject data if filename matches pattern
                thisSub_data['subject']=sub_name
                all_subs_dfs.append(thisSub_data)
                all_subs_data=all_subs_data.append(thisSub_data)
# Out:
# 111_alpha_singleton_pilot_01_2019_May_28_1230.csv
# 112_alpha_singleton_pilot_01_2019_May_31_1458.csv
# 113_alpha_singleton_pilot_01_2019_May_30_1010.csv
# 114_alpha_singleton_pilot_01_2019_May_30_1510.csv
# 115_alpha_singleton_pilot_01_2019_Jun_07_1119.csv
# 116_alpha_singleton_pilot_01_2019_Jun_04_1231.csv
# 117_alpha_singleton_pilot_01_2019_Jun_05_1006.csv
# 118_alpha_singleton_pilot_01_2019_Jun_06_1405.csv
# 119_alpha_singleton_pilot_01_2019_Jun_06_1540.csv
# 122_alpha_singleton_pilot_01_2019_Jun_14_1354.csv
# 123_alpha_singleton_pilot_01_2019_Jun_13_0913.csv
# 124_alpha_singleton_pilot_01_2019_Jun_14_1531.csv
# 125_alpha_singleton_pilot_01_2019_Jun_25_0900.csv
# 126_alpha_singleton_pilot_01_2019_Jun_20_1541.csv

# %%
all_subs_data
# Out:
#      block  trialNum trial_type dis_PresentorAbsent corrResp subResp  \
# 0        0         0        dis             Present       up      up
# 1        0         1        dis             Present     left    left
# 2        0         2        dis             Present       up      up
# 3        0         3        dis             Present       up    left
# 4        0         4       neut             Present     left    left
# 5        0         5       neut             Present     left    left
# 6        0         6        dis             Present     left    left
# 7        0         7        dis             Present     left    None
# 8        0         8       neut              Absent     left    left
# 9        0         9        dis             Present       up      up
# 10       0        10       neut              Absent     left    left
# 11       0        11       neut              Absent     left    left
# 12       0        12       neut             Present       up      up
# 13       0        13       neut              Absent     left    left
# 14       0        14        dis             Present       up    left
# 15       0        15        dis             Present       up      up
# 16       0        16       neut              Absent       up      up
# 17       0        17        dis             Present     left      up
# 18       0        18        dis             Present       up      up
# 19       0        19        dis             Present       up    left
# 20       0        20        dis             Present       up      up
# 21       0        21       neut              Absent       up      up
# 22       0        22       neut             Present     left    left
# 23       0        23       neut             Present       up    None
# 24       0        24       neut             Present       up      up
# 25       0        25       neut             Present       up      up
# 26       0        26       neut              Absent       up      up
# 27       0        27       neut              Absent     left    left
# 28       0        28       neut              Absent     left    left
# 29       0        29       neut             Present       up      up
# ..     ...       ...        ...                 ...      ...     ...
# 210      4        18       neut             Present       up      up
# 211      4        19        dis             Present     left    left
# 212      4        20        dis             Present       up      up
# 213      4        21        dis             Present       up      up
# 214      4        22        dis             Present       up      up
# 215      4        23        dis             Present       up      up
# 216      4        24       neut              Absent       up      up
# 217      4        25       neut             Present     left    left
# 218      4        26       neut             Present       up      up
# 219      4        27        dis             Present       up      up
# 220      4        28       neut              Absent     left    left
# 221      4        29        dis             Present       up      up
# 222      4        30        dis             Present       up      up
# 223      4        31        dis             Present       up      up
# 224      4        32        dis             Present     left    left
# 225      4        33       neut             Present     left    left
# 226      4        34       neut              Absent       up      up
# 227      4        35        dis             Present       up      up
# 228      4        36       neut              Absent       up      up
# 229      4        37        dis             Present       up      up
# 230      4        38       neut             Present     left    left
# 231      4        39       neut             Present       up      up
# 232      4        40       neut              Absent       up      up
# 233      4        41        dis             Present     left    left
# 234      4        42        dis             Present     left    left
# 235      4        43       neut              Absent     left    left
# 236      4        44        dis             Present       up      up
# 237      4        45        dis             Present       up      up
# 238      4        46        dis             Present       up      up
# 239      4        47       neut             Present       up      up
#
#      trialCorr?        RT    stim_loc(T,D)  ITI  \
# 0           1.0  1.299657       ('5', '3')  1.9
# 1           1.0  1.048731       ('1', '7')  2.0
# 2           1.0  0.698886      ('11', '5')  2.2
# 3           0.0  0.865413       ('3', '9')  2.1
# 4           1.0  0.815477       ('9', '3')  2.5
# 5           1.0  0.882132      ('11', '1')  2.6
# 6           1.0  1.265370       ('3', '7')  2.4
# 7           NaN       NaN       ('9', '5')  1.6
# 8           1.0  1.598578   ('1', 'noDis')  2.4
# 9           1.0  0.898780       ('5', '9')  2.5
# 10          1.0  0.948796   ('3', 'noDis')  1.8
# 11          1.0  1.331921   ('1', 'noDis')  2.0
# 12          1.0  1.248626      ('3', '11')  1.4
# 13          1.0  0.765493   ('9', 'noDis')  1.7
# 14          0.0  1.082076       ('3', '9')  1.6
# 15          1.0  1.265340       ('7', '9')  1.5
# 16          1.0  1.232051  ('11', 'noDis')  2.0
# 17          0.0  1.149694      ('11', '9')  2.4
# 18          1.0  0.882090       ('7', '1')  2.1
# 19          0.0  0.915425      ('9', '11')  1.8
# 20          1.0  1.115415       ('1', '7')  1.8
# 21          1.0  0.998806   ('5', 'noDis')  1.8
# 22          1.0  0.915400       ('5', '7')  2.6
# 23          NaN       NaN      ('7', '11')  2.1
# 24          1.0  1.365262       ('5', '3')  1.7
# 25          1.0  0.998747       ('5', '1')  2.6
# 26          1.0  0.615638  ('11', 'noDis')  1.9
# 27          1.0  1.198730   ('9', 'noDis')  2.6
# 28          1.0  0.715523   ('3', 'noDis')  2.2
# 29          1.0  0.532258       ('7', '5')  2.2
# ..          ...       ...              ...  ...
# 210         1.0  1.015445       ('1', '9')  2.6
# 211         1.0  1.032114       ('7', '5')  2.3
# 212         1.0  1.098722       ('7', '9')  1.9
# 213         1.0  0.749930       ('5', '9')  1.9
# 214         1.0  0.932141      ('11', '1')  2.0
# 215         1.0  0.998871       ('3', '7')  1.4
# 216         1.0  1.098813   ('5', 'noDis')  1.9
# 217         1.0  0.998768       ('9', '1')  2.2
# 218         1.0  1.283069       ('5', '1')  2.2
# 219         1.0  1.082061      ('11', '5')  1.8
# 220         1.0  1.098758   ('9', 'noDis')  2.1
# 221         1.0  0.898815      ('11', '7')  1.6
# 222         1.0  1.348710       ('9', '5')  1.7
# 223         1.0  1.215429      ('11', '5')  2.4
# 224         1.0  1.448529       ('1', '9')  2.0
# 225         1.0  0.998804       ('1', '9')  2.5
# 226         1.0  1.132119   ('1', 'noDis')  1.6
# 227         1.0  0.965413       ('7', '1')  1.4
# 228         1.0  0.983130  ('11', 'noDis')  2.3
# 229         1.0  0.716606       ('7', '1')  2.5
# 230         1.0  1.565181      ('3', '11')  2.0
# 231         1.0  1.331988       ('7', '5')  1.9
# 232         1.0  1.282054   ('1', 'noDis')  1.6
# 233         1.0  1.032130      ('9', '11')  1.5
# 234         1.0  1.515296       ('5', '3')  2.2
# 235         1.0  0.916559   ('7', 'noDis')  2.5
# 236         1.0  1.015441      ('11', '3')  2.6
# 237         1.0  0.882173       ('5', '1')  2.5
# 238         1.0  1.415267       ('9', '3')  1.9
# 239         1.0  1.398716      ('11', '1')  1.5
#
#                                          Tar,Dis,Other trial_trigs  triggers  \
# 0        ('blue_diamond', 'red_circle', 'blue_circle')        None       NaN
# 1       ('red_diamond', 'yellow_circle', 'red_circle')        None       NaN
# 2    ('yellow_diamond', 'blue_circle', 'yellow_circ...        None       NaN
# 3    ('yellow_circle', 'red_diamond', 'yellow_diamo...        None       NaN
# 4         ('red_diamond', 'blue_circle', 'red_circle')        None       NaN
# 5         ('red_diamond', 'blue_circle', 'red_circle')        None       NaN
# 6    ('blue_circle', 'yellow_diamond', 'blue_diamond')        None       NaN
# 7        ('red_circle', 'blue_diamond', 'red_diamond')        None       NaN
# 8               ('red_circle', 'noDis', 'red_diamond')        None       NaN
# 9    ('yellow_diamond', 'red_circle', 'yellow_circle')        None       NaN
# 10            ('blue_diamond', 'noDis', 'blue_circle')        None       NaN
# 11              ('red_circle', 'noDis', 'red_diamond')        None       NaN
# 12     ('red_circle', 'yellow_diamond', 'red_diamond')        None       NaN
# 13            ('blue_diamond', 'noDis', 'blue_circle')        None       NaN
# 14    ('blue_diamond', 'yellow_circle', 'blue_circle')        None       NaN
# 15   ('yellow_diamond', 'red_circle', 'yellow_circle')        None       NaN
# 16              ('red_circle', 'noDis', 'red_diamond')        None       NaN
# 17        ('red_diamond', 'blue_circle', 'red_circle')        None       NaN
# 18      ('red_diamond', 'yellow_circle', 'red_circle')        None       NaN
# 19      ('blue_circle', 'red_diamond', 'blue_diamond')        None       NaN
# 20   ('yellow_diamond', 'blue_circle', 'yellow_circ...        None       NaN
# 21        ('yellow_circle', 'noDis', 'yellow_diamond')        None       NaN
# 22       ('blue_diamond', 'red_circle', 'blue_circle')        None       NaN
# 23        ('red_diamond', 'blue_circle', 'red_circle')        None       NaN
# 24      ('red_diamond', 'yellow_circle', 'red_circle')        None       NaN
# 25   ('yellow_diamond', 'blue_circle', 'yellow_circ...        None       NaN
# 26        ('yellow_diamond', 'noDis', 'yellow_circle')        None       NaN
# 27        ('yellow_circle', 'noDis', 'yellow_diamond')        None       NaN
# 28            ('blue_diamond', 'noDis', 'blue_circle')        None       NaN
# 29     ('red_circle', 'yellow_diamond', 'red_diamond')        None       NaN
# ..                                                 ...         ...       ...
# 210      ('blue_diamond', 'red_circle', 'blue_circle')        None       NaN
# 211      ('red_circle', 'blue_diamond', 'red_diamond')        None       NaN
# 212  ('yellow_circle', 'blue_diamond', 'yellow_diam...        None       NaN
# 213    ('red_circle', 'yellow_diamond', 'red_diamond')        None       NaN
# 214      ('blue_diamond', 'red_circle', 'blue_circle')        None       NaN
# 215  ('yellow_diamond', 'red_circle', 'yellow_circle')        None       NaN
# 216             ('red_circle', 'noDis', 'red_diamond')        None       NaN
# 217      ('red_circle', 'blue_diamond', 'red_diamond')        None       NaN
# 218  ('yellow_circle', 'red_diamond', 'yellow_diamo...        None       NaN
# 219      ('blue_diamond', 'red_circle', 'blue_circle')        None       NaN
# 220           ('blue_diamond', 'noDis', 'blue_circle')        None       NaN
# 221  ('yellow_circle', 'red_diamond', 'yellow_diamo...        None       NaN
# 222   ('blue_diamond', 'yellow_circle', 'blue_circle')        None       NaN
# 223  ('yellow_circle', 'blue_diamond', 'yellow_diam...        None       NaN
# 224   ('blue_diamond', 'yellow_circle', 'blue_circle')        None       NaN
# 225  ('blue_circle', 'yellow_diamond', 'blue_diamond')        None       NaN
# 226       ('yellow_circle', 'noDis', 'yellow_diamond')        None       NaN
# 227  ('yellow_circle', 'red_diamond', 'yellow_diamo...        None       NaN
# 228       ('yellow_diamond', 'noDis', 'yellow_circle')        None       NaN
# 229  ('yellow_diamond', 'red_circle', 'yellow_circle')        None       NaN
# 230  ('blue_circle', 'yellow_diamond', 'blue_diamond')        None       NaN
# 231  ('blue_circle', 'yellow_diamond', 'blue_diamond')        None       NaN
# 232       ('yellow_diamond', 'noDis', 'yellow_circle')        None       NaN
# 233       ('red_diamond', 'blue_circle', 'red_circle')        None       NaN
# 234  ('yellow_diamond', 'blue_circle', 'yellow_circ...        None       NaN
# 235           ('blue_diamond', 'noDis', 'blue_circle')        None       NaN
# 236  ('yellow_diamond', 'red_circle', 'yellow_circle')        None       NaN
# 237     ('blue_circle', 'red_diamond', 'blue_diamond')        None       NaN
# 238  ('yellow_diamond', 'blue_circle', 'yellow_circ...        None       NaN
# 239      ('red_circle', 'blue_diamond', 'red_diamond')        None       NaN
#
#     subject
# 0       111
# 1       111
# 2       111
# 3       111
# 4       111
# 5       111
# 6       111
# 7       111
# 8       111
# 9       111
# 10      111
# 11      111
# 12      111
# 13      111
# 14      111
# 15      111
# 16      111
# 17      111
# 18      111
# 19      111
# 20      111
# 21      111
# 22      111
# 23      111
# 24      111
# 25      111
# 26      111
# 27      111
# 28      111
# 29      111
# ..      ...
# 210     126
# 211     126
# 212     126
# 213     126
# 214     126
# 215     126
# 216     126
# 217     126
# 218     126
# 219     126
# 220     126
# 221     126
# 222     126
# 223     126
# 224     126
# 225     126
# 226     126
# 227     126
# 228     126
# 229     126
# 230     126
# 231     126
# 232     126
# 233     126
# 234     126
# 235     126
# 236     126
# 237     126
# 238     126
# 239     126
#
# [7728 rows x 14 columns]

# %%
#sub111
all_subs_dfs[0].groupby(['trial_type','dis_PresentorAbsent']).mean() #fewer trials--only did four blocks
# Out:
#                                 block   trialNum  trialCorr?        RT  \
# trial_type dis_PresentorAbsent
# dis        Present                1.5  46.588542    0.848168  0.938764
# neut       Absent                 1.5  47.218750    0.797872  0.943755
#            Present                1.5  49.604167    0.884211  0.967063
#
#                                      ITI  triggers
# trial_type dis_PresentorAbsent
# dis        Present              2.010417       NaN
# neut       Absent               2.035417       NaN
#            Present              2.001042       NaN

# %%
#sub112
all_subs_dfs[1].groupby(['trial_type','dis_PresentorAbsent'])['RT','trialCorr?'].mean()
# Out:
#                                       RT  trialCorr?
# trial_type dis_PresentorAbsent
# dis        Present              1.282671    0.989189
# neut       Absent               1.252548    1.000000
#            Present              1.245763    0.994505

# %%
#sub113
all_subs_dfs[2].groupby(['trial_type','dis_PresentorAbsent'])['RT','trialCorr?'].mean()
# Out:
#                                       RT  trialCorr?
# trial_type dis_PresentorAbsent
# dis        Present              0.791953    0.966057
# neut       Absent               0.685260    0.994792
#            Present              0.845170    0.984375

# %%
#sub114
all_subs_dfs[3].groupby(['trial_type','dis_PresentorAbsent'])['RT','trialCorr?'].mean()
# Out:
#                                       RT  trialCorr?
# trial_type dis_PresentorAbsent
# dis        Present              1.251501    0.994460
# neut       Absent               1.174455    0.994565
#            Present              1.279859    0.988889

# %%
a=all_subs_data.copy()

# %%
a.block[0]=4
# Out:
# /home/dcellier/condaenvs/p3env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
all_subs_data.groupby(['trial_type','dis_PresentorAbsent'])['RT','trialCorr?'].mean()
# Out:
#                                       RT  trialCorr?
# trial_type dis_PresentorAbsent
# dis        Present              1.015875    0.959114
# neut       Absent               0.939874    0.967488
#            Present              1.029045    0.960888

# %% [markdown]
# ## plot difference between cues subject by subject

# %%
.015/.3
# Out:
# 0.05

# %%
import scipy
from scipy.stats import ttest_ind
import seaborn as sns

# %%
gpby=all_subs_data.groupby(['subject','trial_type','dis_PresentorAbsent']).mean()
gpby#.columns
# Out:
#                                         block   trialNum  trialCorr?  \
# subject trial_type dis_PresentorAbsent
# 111     dis        Present                1.5  46.588542    0.848168
#         neut       Absent                 1.5  47.218750    0.797872
#                    Present                1.5  49.604167    0.884211
# 112     dis        Present                3.5  47.252604    0.989189
#         neut       Absent                 3.5  48.656250    1.000000
#                    Present                3.5  46.838542    0.994505
# 113     dis        Present                3.5  47.770833    0.966057
#         neut       Absent                 3.5  46.276042    0.994792
#                    Present                3.5  48.182292    0.984375
# 114     dis        Present                3.5  45.354167    0.994460
#         neut       Absent                 3.5  51.864583    0.994565
#                    Present                3.5  47.427083    0.988889
# 115     dis        Present                3.5  46.611979    0.867188
#         neut       Absent                 3.5  48.265625    0.906250
#                    Present                3.5  48.510417    0.863874
# 116     dis        Present                3.5  47.841146    0.986772
#         neut       Absent                 3.5  45.635417    0.978947
#                    Present                3.5  48.682292    0.989474
# 117     dis        Present                3.5  45.414062    0.958225
#         neut       Absent                 3.5  50.651042    0.984375
#                    Present                3.5  48.520833    0.989583
# 118     dis        Present                3.5  47.429688    0.992105
#         neut       Absent                 3.5  50.203125    1.000000
#                    Present                3.5  44.937500    0.984375
# 119     dis        Present                3.5  46.229167    0.973262
#         neut       Absent                 3.5  47.875000    0.973404
#                    Present                3.5  49.666667    0.973404
# 122     dis        Present                2.0  24.208333    0.915254
#         neut       Absent                 2.0  24.200000    0.933333
#                    Present                2.0  21.383333    0.915254
# 123     dis        Present                2.0  24.316667    1.000000
#         neut       Absent                 2.0  23.750000    1.000000
#                    Present                2.0  21.616667    1.000000
# 124     dis        Present                2.0  23.491667    0.939130
#         neut       Absent                 2.0  21.366667    0.964912
#                    Present                2.0  25.650000    0.862069
# 125     dis        Present                2.0  22.841667    0.974576
#         neut       Absent                 2.0  22.333333    0.950000
#                    Present                2.0  25.983333    0.913793
# 126     dis        Present                2.0  24.066667    0.983193
#         neut       Absent                 2.0  24.050000    0.966102
#                    Present                2.0  21.816667    0.982456
#
#                                               RT       ITI  triggers
# subject trial_type dis_PresentorAbsent
# 111     dis        Present              0.938764  2.010417       NaN
#         neut       Absent               0.943755  2.035417       NaN
#                    Present              0.967063  2.001042       NaN
# 112     dis        Present              1.282671  1.982031       NaN
#         neut       Absent               1.252548  2.027083       NaN
#                    Present              1.245763  1.998958       NaN
# 113     dis        Present              0.791953  1.992708       NaN
#         neut       Absent               0.685260  1.984375       NaN
#                    Present              0.845170  1.982813       NaN
# 114     dis        Present              1.251501  1.979167       NaN
#         neut       Absent               1.174455  1.973958       NaN
#                    Present              1.279859  1.948958       NaN
# 115     dis        Present              0.759163  1.995313       NaN
#         neut       Absent               0.710942  1.998958       NaN
#                    Present              0.789381  1.966146       NaN
# 116     dis        Present              0.973602  1.969531       NaN
#         neut       Absent               0.893833  1.974479       NaN
#                    Present              0.987153  1.994792       NaN
# 117     dis        Present              0.823054  2.020573       NaN
#         neut       Absent               0.746883  2.023958       NaN
#                    Present              0.894876  2.011458       NaN
# 118     dis        Present              1.130506  2.000781       NaN
#         neut       Absent               0.999211  2.029167       NaN
#                    Present              1.084354  1.986979       NaN
# 119     dis        Present              1.141609  1.997656       NaN
#         neut       Absent               0.992040  2.012500       NaN
#                    Present              1.080695  2.012500       NaN
# 122     dis        Present              0.915502  2.035833       NaN
#         neut       Absent               0.892743  2.000000       NaN
#                    Present              0.944233  1.863333       NaN
# 123     dis        Present              1.093547  2.046667       NaN
#         neut       Absent               1.025784  2.033333       NaN
#                    Present              1.061700  2.013333       NaN
# 124     dis        Present              1.005949  1.994167       NaN
#         neut       Absent               0.905349  1.941667       NaN
#                    Present              1.068002  2.051667       NaN
# 125     dis        Present              1.123342  1.985000       NaN
#         neut       Absent               1.097441  1.918333       NaN
#                    Present              1.159975  1.996667       NaN
# 126     dis        Present              1.064229  1.978333       NaN
#         neut       Absent               1.035344  1.998333       NaN
#                    Present              1.187402  1.966667       NaN

# %%
#sns.catplot(y='RT',x='trialCorr?',kind='bar',data=gpby,palette='rocket')

# %%
gpby.keys()
# Out:
# Index(['block', 'trialNum', 'trialCorr?', 'RT', 'ITI', 'triggers'], dtype='object')

# %%
sub_126=(all_subs_data[all_subs_data['subject']=='126']).groupby(['trial_type','dis_PresentorAbsent']).mean()

# %%
sub_126
# Out:
#                                 block   trialNum  trialCorr?        RT  \
# trial_type dis_PresentorAbsent
# dis        Present                2.0  24.066667    0.983193  1.064229
# neut       Absent                 2.0  24.050000    0.966102  1.035344
#            Present                2.0  21.816667    0.982456  1.187402
#
#                                      ITI  triggers
# trial_type dis_PresentorAbsent
# dis        Present              1.978333       NaN
# neut       Absent               1.998333       NaN
#            Present              1.966667       NaN

# %%
sub_126['RT']['neut']['Present']-sub_126['RT']['dis']['Present']
# Out:
# 0.12317249503280325

# %%
diff_dat={'subjects':[],'cue_effect':[],'dis_effect':[]}
for sub in subjects9:
    sub_grpby=(all_subs_data[all_subs_data['subject']==sub]).groupby(['trial_type','dis_PresentorAbsent']).mean()
    cue_effect=sub_grpby['RT']['neut']['Present']-sub_grpby['RT']['dis']['Present']
    dis_effect=sub_grpby['RT']['neut']['Present']-sub_grpby['RT']['neut']['Absent']
    diff_dat['subjects'].append(sub)
    diff_dat['cue_effect'].append(cue_effect)
    diff_dat['dis_effect'].append(dis_effect)

# %%
diff_dat
# Out:
# {'subjects': ['111',
#   '112',
#   '113',
#   '114',
#   '115',
#   '116',
#   '117',
#   '118',
#   '119',
#   '122',
#   '123',
#   '124',
#   '125',
#   '126'],
#  'cue_effect': [0.02829833382746838,
#   -0.036908280124950954,
#   0.05321729878086123,
#   0.028358375774028444,
#   0.0302182875963527,
#   0.013550350398078614,
#   0.07182206130755175,
#   -0.046152468437924865,
#   -0.060913417245622714,
#   0.028730702755331627,
#   -0.03184684081878597,
#   0.062053003008971874,
#   0.03663240008638513,
#   0.12317249503280325],
#  'dis_effect': [0.023307181099263552,
#   -0.006785472721202224,
#   0.1599103648310347,
#   0.1054045323502335,
#   0.07843952974504709,
#   0.09332003781164533,
#   0.1479937286920041,
#   0.0851423506059964,
#   0.08865543658354935,
#   0.05149036363202841,
#   0.03591619503985255,
#   0.16265249157266193,
#   0.0625336272429935,
#   0.1520574058086397]}

# %%
sub_diffs=pd.DataFrame(data=diff_dat)
#sub_diffs['subject']=subjects9
#sub_diffs.columns.append('cue')

# %%
sub_diffs
# Out:
#    subjects  cue_effect  dis_effect
# 0       111    0.028298    0.023307
# 1       112   -0.036908   -0.006785
# 2       113    0.053217    0.159910
# 3       114    0.028358    0.105405
# 4       115    0.030218    0.078440
# 5       116    0.013550    0.093320
# 6       117    0.071822    0.147994
# 7       118   -0.046152    0.085142
# 8       119   -0.060913    0.088655
# 9       122    0.028731    0.051490
# 10      123   -0.031847    0.035916
# 11      124    0.062053    0.162652
# 12      125    0.036632    0.062534
# 13      126    0.123172    0.152057

# %%
sns.catplot(y='cue_effect',x='subjects',kind='point',data=sub_diffs,palette='husl')

# %%
sns.catplot(y='dis_effect',x='subjects',kind='point',data=sub_diffs,palette='rocket')
